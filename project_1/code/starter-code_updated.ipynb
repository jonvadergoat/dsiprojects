# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd # import numpy library as np
import numpy as np  # import pandas library as pd
import matplotlib.pyplot as plt # IMport matplot.lib.pyplot as plt
import seaborn as sns # import seaborn library as sns

# %%
act_2017 = pd.read_csv('datasets/act_2017.csv')    #read csv file
act_2018 = pd.read_csv('datasets/act_2018_updated.csv')
sat_2017 = pd.read_csv('datasets/sat_2017.csv')
sat_2018 = pd.read_csv('datasets/sat_2018.csv')
act_2017_web= pd.read_csv('datasets/act_2017_fromweb.csv')
sat_2017_web= pd.read_csv('datasets/sat_2017_fromweb.csv')

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# 8   468    950
# 9   497   1017

# %%
act_2017.shape
# Out:
# (52, 7)

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:Appears to have a wirde range of values for participation with Alabama having a participation rate of 5% and states like Delaware and Connecticut having 100% participation rate.
#
# Appears that lower participation rate in either test , correlatres with higher scores for that specific test.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:function naan

# %%
act_2017.isnull().sum() #checking act_2017 scores and summing null character values
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
sat_2017.isnull().sum() #checking sat_2017 scores and summing null character values , yes both data no null values look complete
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
sat_2017[sat_2017['Math']==52]  #extremely low math score for maryland
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
sat_2017_web[sat_2017['State']=='Maryland'] #as we see here the actual web data math score for maryland is 524 and not 52
# Out:
#        State Participation  ERW  Math  Total
# 20  Maryland           69%  536   524   1060

# %%
#thus we need to assign the correct data form the data set"sat_2017_web" to "sat_2017"
sat_2017.loc[20,'Math']=sat_2017_web['Math'][20]

# %%
act_2017[act_2017['Science']==2.3] # check against the mean , seems odd as it is extremely low
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
act_2017_web.head(21) #maryland score from science link is actually 23.2
# Out:
#               Unnamed: 0  Participation Rate  Composite  English  Math  \
# 0                Alabama                 100       19.2     18.9  18.4
# 1                 Alaska                  65       19.8     18.7  19.8
# 2                Arizona                  62       19.7     18.6  19.8
# 3               Arkansas                 100       19.4     18.9  19.0
# 4             California                  31       22.8     22.5  22.7
# 5               Colorado                 100       20.8     20.1  20.3
# 6            Connecticut                  31       25.2     25.5  24.6
# 7               Delaware                  18       24.1     24.1  23.4
# 8   District of Columbia                  32       24.2     24.4  23.5
# 9                Florida                  73       19.8     19.0  19.4
# 10               Georgia                  55       21.4     21.0  20.9
# 11                Hawaii                  90       19.0     17.8  19.2
# 12                 Idaho                  38       22.3     21.9  21.8
# 13              Illinois                  93       21.4     21.0  21.2
# 14               Indiana                  35       22.6     22.0  22.4
# 15                  Iowa                  67       21.9     21.2  21.3
# 16                Kansas                  73       21.7     21.1  21.3
# 17              Kentucky                 100       20.0     19.6  19.4
# 18             Louisiana                 100       19.5     19.4  18.8
# 19                 Maine                   8       24.3     24.2  24.0
# 20              Maryland                  28       23.6     23.3  23.1
#
#     Reading  Science
# 0      19.7     19.4
# 1      20.4     19.9
# 2      20.1     19.8
# 3      19.7     19.5
# 4      23.1     22.2
# 5      21.2     20.9
# 6      25.6     24.6
# 7      24.8     23.6
# 8      24.9     23.5
# 9      21.0     19.4
# 10     22.0     21.3
# 11     19.2     19.3
# 12     23.0     22.1
# 13     21.6     21.3
# 14     23.2     22.3
# 15     22.6     22.1
# 16     22.3     21.7
# 17     20.5     20.1
# 18     19.8     19.6
# 19     24.8     23.7
# 20     24.2     23.2

# %%
#thus we assign the correct sciece value from web act_2017 scores from web to act_2017 dataset.

act_2017.loc[21, 'Science']=act_2017_web['Science'][20]

# %%
act_2017.head(52)# checked and science is changed to 23.2
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# 12                Hawaii           90%     17.8  19.2     19.2     19.3
# 13                 Idaho           38%     21.9  21.8     23.0     22.1
# 14              Illinois           93%     21.0  21.2     21.6     21.3
# 15               Indiana           35%     22.0  22.4     23.2     22.3
# 16                  Iowa           67%     21.2  21.3     22.6     22.1
# 17                Kansas           73%     21.1  21.3     22.3     21.7
# 18              Kentucky          100%     19.6  19.4     20.5     20.1
# 19             Louisiana          100%     19.4  18.8     19.8     19.6
# 20                 Maine            8%     24.2  24.0     24.8     23.7
# 21              Maryland           28%     23.3  23.1     24.2     23.2
# 22         Massachusetts           29%     25.4  25.3     25.9     24.7
# 23              Michigan           29%     24.1  23.7     24.5     23.8
# 24             Minnesota          100%     20.4  21.5     21.8     21.6
# 25           Mississippi          100%     18.2  18.1     18.8     18.8
# 26              Missouri          100%     19.8  19.9     20.8     20.5
# 27               Montana          100%     19.0  20.2     21.0     20.5
# 28              Nebraska           84%     20.9  20.9     21.9     21.5
# 29                Nevada          100%     16.3  18.0     18.1     18.2
# 30         New Hampshire           18%     25.4  25.1     26.0     24.9
# 31            New Jersey           34%     23.8  23.8     24.1     23.2
# 32            New Mexico           66%     18.6  19.4     20.4     20.0
# 33              New York           31%     23.8  24.0     24.6     23.9
# 34        North Carolina          100%     17.8  19.3     19.6     19.3
# 35          North Dakota           98%     19.0  20.4     20.5     20.6
# 36                  Ohio           75%     21.2  21.6     22.5     22.0
# 37              Oklahoma          100%     18.5  18.8     20.1     19.6
# 38                Oregon           40%     21.2  21.5     22.4     21.7
# 39          Pennsylvania           23%     23.4  23.4     24.2     23.3
# 40          Rhode Island           21%     24.0  23.3     24.7     23.4
# 41        South Carolina          100%     17.5  18.6     19.1     18.9
# 42          South Dakota           80%     20.7  21.5     22.3     22.0
# 43             Tennessee          100%     19.5  19.2     20.1     19.9
# 44                 Texas           45%     19.5  20.7     21.1     20.9
# 45                  Utah          100%     19.5  19.9     20.8     20.6
# 46               Vermont           29%     23.3  23.1     24.4     23.2
# 47              Virginia           29%     23.5  23.3     24.6     23.5
# 48            Washington           29%     20.9  21.9     22.1     22.0
# 49         West Virginia           69%     20.0  19.4     21.2     20.5
# 50             Wisconsin          100%     19.7  20.4     20.6     20.9
# 51               Wyoming          100%     19.4  19.8     20.8     20.6
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# 6       20.8
# 7       25.2
# 8       24.1
# 9       24.2
# 10      19.8
# 11      21.4
# 12      19.0
# 13      22.3
# 14      21.4
# 15      22.6
# 16      21.9
# 17      21.7
# 18      20.0
# 19      19.5
# 20      24.3
# 21      23.6
# 22      25.4
# 23      24.1
# 24      21.5
# 25      18.6
# 26      20.4
# 27      20.3
# 28      21.4
# 29      17.8
# 30      25.5
# 31      23.9
# 32      19.7
# 33      24.2
# 34      19.1
# 35      20.3
# 36      22.0
# 37      19.4
# 38      21.8
# 39      23.7
# 40      24.0
# 41      18.7
# 42      21.8
# 43      19.8
# 44      20.7
# 45      20.3
# 46      23.6
# 47      23.8
# 48      21.9
# 49      20.4
# 50      20.5
# 51     20.2x

# %%
#assigning the correct data from the data set from act_2017_web link to the act_2017

act_2017.loc[51,'Composite']=act_2017_web['Composite'][50]

# %%
act_2017 #checking act_2017 scores for wyoming got replaced for 20.2x to 20.2
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# 12                Hawaii           90%     17.8  19.2     19.2     19.3
# 13                 Idaho           38%     21.9  21.8     23.0     22.1
# 14              Illinois           93%     21.0  21.2     21.6     21.3
# 15               Indiana           35%     22.0  22.4     23.2     22.3
# 16                  Iowa           67%     21.2  21.3     22.6     22.1
# 17                Kansas           73%     21.1  21.3     22.3     21.7
# 18              Kentucky          100%     19.6  19.4     20.5     20.1
# 19             Louisiana          100%     19.4  18.8     19.8     19.6
# 20                 Maine            8%     24.2  24.0     24.8     23.7
# 21              Maryland           28%     23.3  23.1     24.2     23.2
# 22         Massachusetts           29%     25.4  25.3     25.9     24.7
# 23              Michigan           29%     24.1  23.7     24.5     23.8
# 24             Minnesota          100%     20.4  21.5     21.8     21.6
# 25           Mississippi          100%     18.2  18.1     18.8     18.8
# 26              Missouri          100%     19.8  19.9     20.8     20.5
# 27               Montana          100%     19.0  20.2     21.0     20.5
# 28              Nebraska           84%     20.9  20.9     21.9     21.5
# 29                Nevada          100%     16.3  18.0     18.1     18.2
# 30         New Hampshire           18%     25.4  25.1     26.0     24.9
# 31            New Jersey           34%     23.8  23.8     24.1     23.2
# 32            New Mexico           66%     18.6  19.4     20.4     20.0
# 33              New York           31%     23.8  24.0     24.6     23.9
# 34        North Carolina          100%     17.8  19.3     19.6     19.3
# 35          North Dakota           98%     19.0  20.4     20.5     20.6
# 36                  Ohio           75%     21.2  21.6     22.5     22.0
# 37              Oklahoma          100%     18.5  18.8     20.1     19.6
# 38                Oregon           40%     21.2  21.5     22.4     21.7
# 39          Pennsylvania           23%     23.4  23.4     24.2     23.3
# 40          Rhode Island           21%     24.0  23.3     24.7     23.4
# 41        South Carolina          100%     17.5  18.6     19.1     18.9
# 42          South Dakota           80%     20.7  21.5     22.3     22.0
# 43             Tennessee          100%     19.5  19.2     20.1     19.9
# 44                 Texas           45%     19.5  20.7     21.1     20.9
# 45                  Utah          100%     19.5  19.9     20.8     20.6
# 46               Vermont           29%     23.3  23.1     24.4     23.2
# 47              Virginia           29%     23.5  23.3     24.6     23.5
# 48            Washington           29%     20.9  21.9     22.1     22.0
# 49         West Virginia           69%     20.0  19.4     21.2     20.5
# 50             Wisconsin          100%     19.7  20.4     20.6     20.9
# 51               Wyoming          100%     19.4  19.8     20.8     20.6
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# 6       20.8
# 7       25.2
# 8       24.1
# 9       24.2
# 10      19.8
# 11      21.4
# 12      19.0
# 13      22.3
# 14      21.4
# 15      22.6
# 16      21.9
# 17      21.7
# 18      20.0
# 19      19.5
# 20      24.3
# 21      23.6
# 22      25.4
# 23      24.1
# 24      21.5
# 25      18.6
# 26      20.4
# 27      20.3
# 28      21.4
# 29      17.8
# 30      25.5
# 31      23.9
# 32      19.7
# 33      24.2
# 34      19.1
# 35      20.3
# 36      22.0
# 37      19.4
# 38      21.8
# 39      23.7
# 40      24.0
# 41      18.7
# 42      21.8
# 43      19.8
# 44      20.7
# 45      20.3
# 46      23.6
# 47      23.8
# 48      21.9
# 49      20.4
# 50      20.5
# 51      20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
act_2017.info() # using info function to check data ypes of act_2017 and columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
sat_2017.info()  # using info function to check data ypes of sat_2017 and columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# participation should be an integer not object therefore it must have been read as a string,
# Composite score should have been an integer as well , not an object.

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:the SAT Scores lowest is 400.
# and also the ACT scores range from 1-36.
#
# cross referencing from the articles

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# using the str function and replacing the %  for both act_2017 and sat_2017
act_2017['Participation']=act_2017['Participation'].str.replace('%','')
sat_2017['Participation']=sat_2017['Participation'].str.replace('%','')

# %%
#code function that tries to returna. float , else it will return NAN
def to_float(x):
    try: 
        out= float(x)
    except:
        out= np.nan
    return out

# %%
#changing values under composite to float for act_2017
act_2017['Composite'] = act_2017['Composite'].apply(to_float)

# %%
#using the float function to change values under participation to float valuies

act_2017['Participation'] = act_2017['Participation'].apply(to_float)

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
#using the same float function to change values under math , evidence based reading and writing , total , participation to float values

sat_2017['Math']=sat_2017['Math'].apply(to_float)
sat_2017['Evidence-Based Reading and Writing']= sat_2017['Evidence-Based Reading and Writing'].apply(to_float)
sat_2017['Total']=sat_2017['Total'].apply(to_float)
sat_2017['Participation']=sat_2017['Participation'].apply(to_float)

# %%
sat_2017.info() # check all the data types are converted to float other than state
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     float64
#  3   Math                                51 non-null     float64
#  4   Total                               51 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act_2017.info()# checking the datatypes of act_2017 all are float values except state correct.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
#converting all column names to lowercase , also remove space with _
sat_2017.columns = sat_2017.columns.str.lower()
sat_2017.columns = sat_2017.columns.str.replace(' ','_')

# %%
sat_2017.columns #check
# Out:
# Index(['state', 'participation', 'evidence-based_reading_and_writing', 'math',
#        'total'],
#       dtype='object')

# %%
#conveting all act 2017 column values to be lowercase and replacing space for _
act_2017.columns =act_2017.columns.str.lower()
act_2017.columns = act_2017.columns.str.replace(' ','_')

# %%
act_2017.columns
# Out:
# Index(['state', 'participation', 'english', 'math', 'reading', 'science',
#        'composite'],
#       dtype='object')

# %%
#utilizing list comprehension to concatenate the column nates in the dataset sat_2017 with "_Sat_2017"
sat_2017.columns=[n+'_sat_2017' for n in sat_2017.columns]

# %%
sat_2017.head(52)
# Out:
#           state_sat_2017  participation_sat_2017  \
# 0                Alabama                     5.0
# 1                 Alaska                    38.0
# 2                Arizona                    30.0
# 3               Arkansas                     3.0
# 4             California                    53.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 9                Florida                    83.0
# 10               Georgia                    61.0
# 11                Hawaii                    55.0
# 12                 Idaho                    93.0
# 13              Illinois                     9.0
# 14               Indiana                    63.0
# 15                  Iowa                     2.0
# 16                Kansas                     4.0
# 17              Kentucky                     4.0
# 18             Louisiana                     4.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
# 21         Massachusetts                    76.0
# 22              Michigan                   100.0
# 23             Minnesota                     3.0
# 24           Mississippi                     2.0
# 25              Missouri                     3.0
# 26               Montana                    10.0
# 27              Nebraska                     3.0
# 28                Nevada                    26.0
# 29         New Hampshire                    96.0
# 30            New Jersey                    70.0
# 31            New Mexico                    11.0
# 32              New York                    67.0
# 33        North Carolina                    49.0
# 34          North Dakota                     2.0
# 35                  Ohio                    12.0
# 36              Oklahoma                     7.0
# 37                Oregon                    43.0
# 38          Pennsylvania                    65.0
# 39          Rhode Island                    71.0
# 40        South Carolina                    50.0
# 41          South Dakota                     3.0
# 42             Tennessee                     5.0
# 43                 Texas                    62.0
# 44                  Utah                     3.0
# 45               Vermont                    60.0
# 46              Virginia                    65.0
# 47            Washington                    64.0
# 48         West Virginia                    14.0
# 49             Wisconsin                     3.0
# 50               Wyoming                     3.0
#
#     evidence-based_reading_and_writing_sat_2017  math_sat_2017  total_sat_2017
# 0                                         593.0          572.0          1165.0
# 1                                         547.0          533.0          1080.0
# 2                                         563.0          553.0          1116.0
# 3                                         614.0          594.0          1208.0
# 4                                         531.0          524.0          1055.0
# 5                                         606.0          595.0          1201.0
# 6                                         530.0          512.0          1041.0
# 7                                         503.0          492.0           996.0
# 8                                         482.0          468.0           950.0
# 9                                         520.0          497.0          1017.0
# 10                                        535.0          515.0          1050.0
# 11                                        544.0          541.0          1085.0
# 12                                        513.0          493.0          1005.0
# 13                                        559.0          556.0          1115.0
# 14                                        542.0          532.0          1074.0
# 15                                        641.0          635.0          1275.0
# 16                                        632.0          628.0          1260.0
# 17                                        631.0          616.0          1247.0
# 18                                        611.0          586.0          1198.0
# 19                                        513.0          499.0          1012.0
# 20                                        536.0          524.0          1060.0
# 21                                        555.0          551.0          1107.0
# 22                                        509.0          495.0          1005.0
# 23                                        644.0          651.0          1295.0
# 24                                        634.0          607.0          1242.0
# 25                                        640.0          631.0          1271.0
# 26                                        605.0          591.0          1196.0
# 27                                        629.0          625.0          1253.0
# 28                                        563.0          553.0          1116.0
# 29                                        532.0          520.0          1052.0
# 30                                        530.0          526.0          1056.0
# 31                                        577.0          561.0          1138.0
# 32                                        528.0          523.0          1052.0
# 33                                        546.0          535.0          1081.0
# 34                                        635.0          621.0          1256.0
# 35                                        578.0          570.0          1149.0
# 36                                        530.0          517.0          1047.0
# 37                                        560.0          548.0          1108.0
# 38                                        540.0          531.0          1071.0
# 39                                        539.0          524.0          1062.0
# 40                                        543.0          521.0          1064.0
# 41                                        612.0          603.0          1216.0
# 42                                        623.0          604.0          1228.0
# 43                                        513.0          507.0          1020.0
# 44                                        624.0          614.0          1238.0
# 45                                        562.0          551.0          1114.0
# 46                                        561.0          541.0          1102.0
# 47                                        541.0          534.0          1075.0
# 48                                        558.0          528.0          1086.0
# 49                                        642.0          649.0          1291.0
# 50                                        626.0          604.0          1230.0

# %%
#utilizing list comprehension to concatenate the column nates in the dataset act_2017 with "_act_2017"
act_2017.columns=[n+'_act_2017' for n in act_2017.columns]

# %%
 act_2017.head(52) # to check if column names are changed
# Out:
#           state_act_2017  participation_act_2017  english_act_2017  \
# 1                Alabama                   100.0              18.9
# 2                 Alaska                    65.0              18.7
# 3                Arizona                    62.0              18.6
# 4               Arkansas                   100.0              18.9
# 5             California                    31.0              22.5
# 6               Colorado                   100.0              20.1
# 7            Connecticut                    31.0              25.5
# 8               Delaware                    18.0              24.1
# 9   District of Columbia                    32.0              24.4
# 10               Florida                    73.0              19.0
# 11               Georgia                    55.0              21.0
# 12                Hawaii                    90.0              17.8
# 13                 Idaho                    38.0              21.9
# 14              Illinois                    93.0              21.0
# 15               Indiana                    35.0              22.0
# 16                  Iowa                    67.0              21.2
# 17                Kansas                    73.0              21.1
# 18              Kentucky                   100.0              19.6
# 19             Louisiana                   100.0              19.4
# 20                 Maine                     8.0              24.2
# 21              Maryland                    28.0              23.3
# 22         Massachusetts                    29.0              25.4
# 23              Michigan                    29.0              24.1
# 24             Minnesota                   100.0              20.4
# 25           Mississippi                   100.0              18.2
# 26              Missouri                   100.0              19.8
# 27               Montana                   100.0              19.0
# 28              Nebraska                    84.0              20.9
# 29                Nevada                   100.0              16.3
# 30         New Hampshire                    18.0              25.4
# 31            New Jersey                    34.0              23.8
# 32            New Mexico                    66.0              18.6
# 33              New York                    31.0              23.8
# 34        North Carolina                   100.0              17.8
# 35          North Dakota                    98.0              19.0
# 36                  Ohio                    75.0              21.2
# 37              Oklahoma                   100.0              18.5
# 38                Oregon                    40.0              21.2
# 39          Pennsylvania                    23.0              23.4
# 40          Rhode Island                    21.0              24.0
# 41        South Carolina                   100.0              17.5
# 42          South Dakota                    80.0              20.7
# 43             Tennessee                   100.0              19.5
# 44                 Texas                    45.0              19.5
# 45                  Utah                   100.0              19.5
# 46               Vermont                    29.0              23.3
# 47              Virginia                    29.0              23.5
# 48            Washington                    29.0              20.9
# 49         West Virginia                    69.0              20.0
# 50             Wisconsin                   100.0              19.7
# 51               Wyoming                   100.0              19.4
#
#     math_act_2017  reading_act_2017  science_act_2017  composite_act_2017
# 1            18.4              19.7              19.4                19.2
# 2            19.8              20.4              19.9                19.8
# 3            19.8              20.1              19.8                19.7
# 4            19.0              19.7              19.5                19.4
# 5            22.7              23.1              22.2                22.8
# 6            20.3              21.2              20.9                20.8
# 7            24.6              25.6              24.6                25.2
# 8            23.4              24.8              23.6                24.1
# 9            23.5              24.9              23.5                24.2
# 10           19.4              21.0              19.4                19.8
# 11           20.9              22.0              21.3                21.4
# 12           19.2              19.2              19.3                19.0
# 13           21.8              23.0              22.1                22.3
# 14           21.2              21.6              21.3                21.4
# 15           22.4              23.2              22.3                22.6
# 16           21.3              22.6              22.1                21.9
# 17           21.3              22.3              21.7                21.7
# 18           19.4              20.5              20.1                20.0
# 19           18.8              19.8              19.6                19.5
# 20           24.0              24.8              23.7                24.3
# 21           23.1              24.2              23.2                23.6
# 22           25.3              25.9              24.7                25.4
# 23           23.7              24.5              23.8                24.1
# 24           21.5              21.8              21.6                21.5
# 25           18.1              18.8              18.8                18.6
# 26           19.9              20.8              20.5                20.4
# 27           20.2              21.0              20.5                20.3
# 28           20.9              21.9              21.5                21.4
# 29           18.0              18.1              18.2                17.8
# 30           25.1              26.0              24.9                25.5
# 31           23.8              24.1              23.2                23.9
# 32           19.4              20.4              20.0                19.7
# 33           24.0              24.6              23.9                24.2
# 34           19.3              19.6              19.3                19.1
# 35           20.4              20.5              20.6                20.3
# 36           21.6              22.5              22.0                22.0
# 37           18.8              20.1              19.6                19.4
# 38           21.5              22.4              21.7                21.8
# 39           23.4              24.2              23.3                23.7
# 40           23.3              24.7              23.4                24.0
# 41           18.6              19.1              18.9                18.7
# 42           21.5              22.3              22.0                21.8
# 43           19.2              20.1              19.9                19.8
# 44           20.7              21.1              20.9                20.7
# 45           19.9              20.8              20.6                20.3
# 46           23.1              24.4              23.2                23.6
# 47           23.3              24.6              23.5                23.8
# 48           21.9              22.1              22.0                21.9
# 49           19.4              21.2              20.5                20.4
# 50           20.4              20.6              20.9                20.5
# 51           19.8              20.8              20.6                20.2

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|Name of the state from data is collected|
# |Participation_sat_2017|float|SAT|Percentage of graduating high school students participated in SAT in 2017|
# |reading_sat_2017|float|SAT|Average score of evidence-based reading and writing section or SAT in 2017|
# |math_sat_2017|float|SAT|Average score of Maths ection for SAT in 2017|
# |total_sat_2017|float|SAT|Average score of SAT score for sat in 2017|
# |participation_act_2017|float|ACT|Percentage of graduating high school students aprticipated in ACT in 2017|
# |english_act_2017|float|ACT| Average score of English section for ACT in 2017|
# |math_act_2017|float|ACT|Average score of Math section for ACT in 2017|
# |reading_act_2017|float|ACT|Average score of reading section for ACT in 2017|
# |composite_act_2017|float|ACT|Average composite score fro ACT in 2017|
# |participation_sat_2018|float|SAT|Percentage of graduating high school students participated in SAT in 2018|
# |reading_sat_2018|float|SAT|Average Score of evidence-based reading and writing section for SAT in 2018|
# |math_sat_2018|float|SAT|Average score of Math section for SAT in 2018|
# |total_sat_2018|float|SAT|Average total SAT score for SAT in 2018|
# |participation_act_2018|float|ACT|percentage of graduating high school studetns participated in ACT in 2018|
# |english_act_2018|float|ACT|Average score of english section for ACT in 2018|
# |math_act_2018|float|ACT|Average score of math section for ACT in 2018|
# |reading_act_2018|float|ACT|Average score of reading section for ACT in 2018|
# |math_act_2018|float|ACT|Average score of math section for ACT in 2018|
# |reading_act_2018|float|ACT|Average score of reading section for ACT in 2018|
# |science_act_2018|float|ACT|Average score of science section for ACT in 2018|
# |composite_act_2018|float|ACT|Average composite score for ACT in 2018|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code drop the first row of act_2017 dataset, inplace true so that we dontneed to create a new variable and its placed back in dataframe
act_2017.drop(0, axis=0, inplace=True)
act_2017.head()
# Out:
#   state_act_2017  participation_act_2017  english_act_2017  math_act_2017  \
# 1        Alabama                   100.0              18.9           18.4
# 2         Alaska                    65.0              18.7           19.8
# 3        Arizona                    62.0              18.6           19.8
# 4       Arkansas                   100.0              18.9           19.0
# 5     California                    31.0              22.5           22.7
#
#    reading_act_2017  science_act_2017  composite_act_2017
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4
# 5              23.1              22.2                22.8

# %%
sat_2017.head(52)
# Out:
#           state_sat_2017  participation_sat_2017  \
# 0                Alabama                     5.0
# 1                 Alaska                    38.0
# 2                Arizona                    30.0
# 3               Arkansas                     3.0
# 4             California                    53.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 9                Florida                    83.0
# 10               Georgia                    61.0
# 11                Hawaii                    55.0
# 12                 Idaho                    93.0
# 13              Illinois                     9.0
# 14               Indiana                    63.0
# 15                  Iowa                     2.0
# 16                Kansas                     4.0
# 17              Kentucky                     4.0
# 18             Louisiana                     4.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
# 21         Massachusetts                    76.0
# 22              Michigan                   100.0
# 23             Minnesota                     3.0
# 24           Mississippi                     2.0
# 25              Missouri                     3.0
# 26               Montana                    10.0
# 27              Nebraska                     3.0
# 28                Nevada                    26.0
# 29         New Hampshire                    96.0
# 30            New Jersey                    70.0
# 31            New Mexico                    11.0
# 32              New York                    67.0
# 33        North Carolina                    49.0
# 34          North Dakota                     2.0
# 35                  Ohio                    12.0
# 36              Oklahoma                     7.0
# 37                Oregon                    43.0
# 38          Pennsylvania                    65.0
# 39          Rhode Island                    71.0
# 40        South Carolina                    50.0
# 41          South Dakota                     3.0
# 42             Tennessee                     5.0
# 43                 Texas                    62.0
# 44                  Utah                     3.0
# 45               Vermont                    60.0
# 46              Virginia                    65.0
# 47            Washington                    64.0
# 48         West Virginia                    14.0
# 49             Wisconsin                     3.0
# 50               Wyoming                     3.0
#
#     evidence-based_reading_and_writing_sat_2017  math_sat_2017  total_sat_2017
# 0                                         593.0          572.0          1165.0
# 1                                         547.0          533.0          1080.0
# 2                                         563.0          553.0          1116.0
# 3                                         614.0          594.0          1208.0
# 4                                         531.0          524.0          1055.0
# 5                                         606.0          595.0          1201.0
# 6                                         530.0          512.0          1041.0
# 7                                         503.0          492.0           996.0
# 8                                         482.0          468.0           950.0
# 9                                         520.0          497.0          1017.0
# 10                                        535.0          515.0          1050.0
# 11                                        544.0          541.0          1085.0
# 12                                        513.0          493.0          1005.0
# 13                                        559.0          556.0          1115.0
# 14                                        542.0          532.0          1074.0
# 15                                        641.0          635.0          1275.0
# 16                                        632.0          628.0          1260.0
# 17                                        631.0          616.0          1247.0
# 18                                        611.0          586.0          1198.0
# 19                                        513.0          499.0          1012.0
# 20                                        536.0          524.0          1060.0
# 21                                        555.0          551.0          1107.0
# 22                                        509.0          495.0          1005.0
# 23                                        644.0          651.0          1295.0
# 24                                        634.0          607.0          1242.0
# 25                                        640.0          631.0          1271.0
# 26                                        605.0          591.0          1196.0
# 27                                        629.0          625.0          1253.0
# 28                                        563.0          553.0          1116.0
# 29                                        532.0          520.0          1052.0
# 30                                        530.0          526.0          1056.0
# 31                                        577.0          561.0          1138.0
# 32                                        528.0          523.0          1052.0
# 33                                        546.0          535.0          1081.0
# 34                                        635.0          621.0          1256.0
# 35                                        578.0          570.0          1149.0
# 36                                        530.0          517.0          1047.0
# 37                                        560.0          548.0          1108.0
# 38                                        540.0          531.0          1071.0
# 39                                        539.0          524.0          1062.0
# 40                                        543.0          521.0          1064.0
# 41                                        612.0          603.0          1216.0
# 42                                        623.0          604.0          1228.0
# 43                                        513.0          507.0          1020.0
# 44                                        624.0          614.0          1238.0
# 45                                        562.0          551.0          1114.0
# 46                                        561.0          541.0          1102.0
# 47                                        541.0          534.0          1075.0
# 48                                        558.0          528.0          1086.0
# 49                                        642.0          649.0          1291.0
# 50                                        626.0          604.0          1230.0

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Applies an outer merge to sat_2017 and act_2017 merging on the state
#This dataframe is saved as combined_2017
combined_2017 = pd.merge(sat_2017,act_2017, left_on= 'state_sat_2017', right_on ='state_act_2017', how ='outer')

# %%
combined_2017.head(52)
# Out:
#           state_sat_2017  participation_sat_2017  \
# 0                Alabama                     5.0
# 1                 Alaska                    38.0
# 2                Arizona                    30.0
# 3               Arkansas                     3.0
# 4             California                    53.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 9                Florida                    83.0
# 10               Georgia                    61.0
# 11                Hawaii                    55.0
# 12                 Idaho                    93.0
# 13              Illinois                     9.0
# 14               Indiana                    63.0
# 15                  Iowa                     2.0
# 16                Kansas                     4.0
# 17              Kentucky                     4.0
# 18             Louisiana                     4.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
# 21         Massachusetts                    76.0
# 22              Michigan                   100.0
# 23             Minnesota                     3.0
# 24           Mississippi                     2.0
# 25              Missouri                     3.0
# 26               Montana                    10.0
# 27              Nebraska                     3.0
# 28                Nevada                    26.0
# 29         New Hampshire                    96.0
# 30            New Jersey                    70.0
# 31            New Mexico                    11.0
# 32              New York                    67.0
# 33        North Carolina                    49.0
# 34          North Dakota                     2.0
# 35                  Ohio                    12.0
# 36              Oklahoma                     7.0
# 37                Oregon                    43.0
# 38          Pennsylvania                    65.0
# 39          Rhode Island                    71.0
# 40        South Carolina                    50.0
# 41          South Dakota                     3.0
# 42             Tennessee                     5.0
# 43                 Texas                    62.0
# 44                  Utah                     3.0
# 45               Vermont                    60.0
# 46              Virginia                    65.0
# 47            Washington                    64.0
# 48         West Virginia                    14.0
# 49             Wisconsin                     3.0
# 50               Wyoming                     3.0
#
#     evidence-based_reading_and_writing_sat_2017  math_sat_2017  \
# 0                                         593.0          572.0
# 1                                         547.0          533.0
# 2                                         563.0          553.0
# 3                                         614.0          594.0
# 4                                         531.0          524.0
# 5                                         606.0          595.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# 8                                         482.0          468.0
# 9                                         520.0          497.0
# 10                                        535.0          515.0
# 11                                        544.0          541.0
# 12                                        513.0          493.0
# 13                                        559.0          556.0
# 14                                        542.0          532.0
# 15                                        641.0          635.0
# 16                                        632.0          628.0
# 17                                        631.0          616.0
# 18                                        611.0          586.0
# 19                                        513.0          499.0
# 20                                        536.0          524.0
# 21                                        555.0          551.0
# 22                                        509.0          495.0
# 23                                        644.0          651.0
# 24                                        634.0          607.0
# 25                                        640.0          631.0
# 26                                        605.0          591.0
# 27                                        629.0          625.0
# 28                                        563.0          553.0
# 29                                        532.0          520.0
# 30                                        530.0          526.0
# 31                                        577.0          561.0
# 32                                        528.0          523.0
# 33                                        546.0          535.0
# 34                                        635.0          621.0
# 35                                        578.0          570.0
# 36                                        530.0          517.0
# 37                                        560.0          548.0
# 38                                        540.0          531.0
# 39                                        539.0          524.0
# 40                                        543.0          521.0
# 41                                        612.0          603.0
# 42                                        623.0          604.0
# 43                                        513.0          507.0
# 44                                        624.0          614.0
# 45                                        562.0          551.0
# 46                                        561.0          541.0
# 47                                        541.0          534.0
# 48                                        558.0          528.0
# 49                                        642.0          649.0
# 50                                        626.0          604.0
#
#     total_sat_2017        state_act_2017  participation_act_2017  \
# 0           1165.0               Alabama                   100.0
# 1           1080.0                Alaska                    65.0
# 2           1116.0               Arizona                    62.0
# 3           1208.0              Arkansas                   100.0
# 4           1055.0            California                    31.0
# 5           1201.0              Colorado                   100.0
# 6           1041.0           Connecticut                    31.0
# 7            996.0              Delaware                    18.0
# 8            950.0  District of Columbia                    32.0
# 9           1017.0               Florida                    73.0
# 10          1050.0               Georgia                    55.0
# 11          1085.0                Hawaii                    90.0
# 12          1005.0                 Idaho                    38.0
# 13          1115.0              Illinois                    93.0
# 14          1074.0               Indiana                    35.0
# 15          1275.0                  Iowa                    67.0
# 16          1260.0                Kansas                    73.0
# 17          1247.0              Kentucky                   100.0
# 18          1198.0             Louisiana                   100.0
# 19          1012.0                 Maine                     8.0
# 20          1060.0              Maryland                    28.0
# 21          1107.0         Massachusetts                    29.0
# 22          1005.0              Michigan                    29.0
# 23          1295.0             Minnesota                   100.0
# 24          1242.0           Mississippi                   100.0
# 25          1271.0              Missouri                   100.0
# 26          1196.0               Montana                   100.0
# 27          1253.0              Nebraska                    84.0
# 28          1116.0                Nevada                   100.0
# 29          1052.0         New Hampshire                    18.0
# 30          1056.0            New Jersey                    34.0
# 31          1138.0            New Mexico                    66.0
# 32          1052.0              New York                    31.0
# 33          1081.0        North Carolina                   100.0
# 34          1256.0          North Dakota                    98.0
# 35          1149.0                  Ohio                    75.0
# 36          1047.0              Oklahoma                   100.0
# 37          1108.0                Oregon                    40.0
# 38          1071.0          Pennsylvania                    23.0
# 39          1062.0          Rhode Island                    21.0
# 40          1064.0        South Carolina                   100.0
# 41          1216.0          South Dakota                    80.0
# 42          1228.0             Tennessee                   100.0
# 43          1020.0                 Texas                    45.0
# 44          1238.0                  Utah                   100.0
# 45          1114.0               Vermont                    29.0
# 46          1102.0              Virginia                    29.0
# 47          1075.0            Washington                    29.0
# 48          1086.0         West Virginia                    69.0
# 49          1291.0             Wisconsin                   100.0
# 50          1230.0               Wyoming                   100.0
#
#     english_act_2017  math_act_2017  reading_act_2017  science_act_2017  \
# 0               18.9           18.4              19.7              19.4
# 1               18.7           19.8              20.4              19.9
# 2               18.6           19.8              20.1              19.8
# 3               18.9           19.0              19.7              19.5
# 4               22.5           22.7              23.1              22.2
# 5               20.1           20.3              21.2              20.9
# 6               25.5           24.6              25.6              24.6
# 7               24.1           23.4              24.8              23.6
# 8               24.4           23.5              24.9              23.5
# 9               19.0           19.4              21.0              19.4
# 10              21.0           20.9              22.0              21.3
# 11              17.8           19.2              19.2              19.3
# 12              21.9           21.8              23.0              22.1
# 13              21.0           21.2              21.6              21.3
# 14              22.0           22.4              23.2              22.3
# 15              21.2           21.3              22.6              22.1
# 16              21.1           21.3              22.3              21.7
# 17              19.6           19.4              20.5              20.1
# 18              19.4           18.8              19.8              19.6
# 19              24.2           24.0              24.8              23.7
# 20              23.3           23.1              24.2              23.2
# 21              25.4           25.3              25.9              24.7
# 22              24.1           23.7              24.5              23.8
# 23              20.4           21.5              21.8              21.6
# 24              18.2           18.1              18.8              18.8
# 25              19.8           19.9              20.8              20.5
# 26              19.0           20.2              21.0              20.5
# 27              20.9           20.9              21.9              21.5
# 28              16.3           18.0              18.1              18.2
# 29              25.4           25.1              26.0              24.9
# 30              23.8           23.8              24.1              23.2
# 31              18.6           19.4              20.4              20.0
# 32              23.8           24.0              24.6              23.9
# 33              17.8           19.3              19.6              19.3
# 34              19.0           20.4              20.5              20.6
# 35              21.2           21.6              22.5              22.0
# 36              18.5           18.8              20.1              19.6
# 37              21.2           21.5              22.4              21.7
# 38              23.4           23.4              24.2              23.3
# 39              24.0           23.3              24.7              23.4
# 40              17.5           18.6              19.1              18.9
# 41              20.7           21.5              22.3              22.0
# 42              19.5           19.2              20.1              19.9
# 43              19.5           20.7              21.1              20.9
# 44              19.5           19.9              20.8              20.6
# 45              23.3           23.1              24.4              23.2
# 46              23.5           23.3              24.6              23.5
# 47              20.9           21.9              22.1              22.0
# 48              20.0           19.4              21.2              20.5
# 49              19.7           20.4              20.6              20.9
# 50              19.4           19.8              20.8              20.6
#
#     composite_act_2017
# 0                 19.2
# 1                 19.8
# 2                 19.7
# 3                 19.4
# 4                 22.8
# 5                 20.8
# 6                 25.2
# 7                 24.1
# 8                 24.2
# 9                 19.8
# 10                21.4
# 11                19.0
# 12                22.3
# 13                21.4
# 14                22.6
# 15                21.9
# 16                21.7
# 17                20.0
# 18                19.5
# 19                24.3
# 20                23.6
# 21                25.4
# 22                24.1
# 23                21.5
# 24                18.6
# 25                20.4
# 26                20.3
# 27                21.4
# 28                17.8
# 29                25.5
# 30                23.9
# 31                19.7
# 32                24.2
# 33                19.1
# 34                20.3
# 35                22.0
# 36                19.4
# 37                21.8
# 38                23.7
# 39                24.0
# 40                18.7
# 41                21.8
# 42                19.8
# 43                20.7
# 44                20.3
# 45                23.6
# 46                23.8
# 47                21.9
# 48                20.4
# 49                20.5
# 50                20.2

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code save it to a relative path
combined_2017.to_csv('combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
act_2018.head(52)
# Out:
#                    State  Percentage of Students Tested  \
# 0                Alabama                            100
# 1                 Alaska                             33
# 2                Arizona                             66
# 3               Arkansas                            100
# 4             California                             27
# 5               Colorado                             30
# 6            Connecticut                             26
# 7               Delaware                             17
# 8   District of Columbia                             32
# 9                Florida                             66
# 10               Georgia                             53
# 11                Hawaii                             89
# 12                 Idaho                             36
# 13              Illinois                             43
# 14               Indiana                             32
# 15                  Iowa                             68
# 16                Kansas                             71
# 17              Kentucky                            100
# 18             Louisiana                            100
# 19                 Maine                              7
# 20              Maryland                             31
# 21         Massachusetts                             25
# 22              Michigan                             22
# 23             Minnesota                             99
# 24           Mississippi                            100
# 25              Missouri                            100
# 26               Montana                            100
# 27              Nebraska                            100
# 28                Nevada                            100
# 29         New Hampshire                             16
# 30            New Jersey                             31
# 31            New Mexico                             67
# 32              New York                             27
# 33        North Carolina                            100
# 34          North Dakota                             98
# 35                  Ohio                            100
# 36              Oklahoma                            100
# 37                Oregon                             42
# 38          Pennsylvania                             20
# 39          Rhode Island                             15
# 40        South Carolina                            100
# 41          South Dakota                             77
# 42             Tennessee                            100
# 43                 Texas                             41
# 44                  Utah                            100
# 45               Vermont                             24
# 46              Virginia                             24
# 47            Washington                             24
# 48         West Virginia                             65
# 49             Wisconsin                            100
# 50               Wyoming                            100
#
#     Average Composite Score  Average English Score  Average Math Score  \
# 0                      19.1                   18.9                18.3
# 1                      20.8                   19.8                20.6
# 2                      19.2                   18.2                19.4
# 3                      19.4                   19.1                18.9
# 4                      22.7                   22.5                22.5
# 5                      23.9                   23.9                23.2
# 6                      25.6                   26.0                24.8
# 7                      23.2                   23.7                23.1
# 8                      23.6                   23.7                22.7
# 9                      19.9                   19.2                19.3
# 10                     21.4                   20.9                20.7
# 11                     18.9                   18.2                19.0
# 12                     22.3                   21.9                21.6
# 13                     23.9                   24.1                23.4
# 14                     22.5                   21.9                22.3
# 15                     21.8                   21.0                21.2
# 16                     21.6                   21.0                21.1
# 17                     20.2                   19.9                19.7
# 18                     19.2                   19.0                18.5
# 19                     24.0                   23.8                23.6
# 20                     22.5                   22.1                22.0
# 21                     25.5                   25.5                25.2
# 22                     24.4                   24.5                23.9
# 23                     21.3                   20.2                21.4
# 24                     18.6                   18.2                18.1
# 25                     20.0                   19.5                19.7
# 26                     20.0                   18.7                19.9
# 27                     20.1                   19.4                19.8
# 28                     17.7                   16.6                17.8
# 29                     25.1                   25.1                24.7
# 30                     23.7                   23.8                23.6
# 31                     19.4                   18.3                19.1
# 32                     24.5                   24.2                24.2
# 33                     19.1                   18.0                19.3
# 34                     20.3                   19.1                20.3
# 35                     20.3                   19.3                20.3
# 36                     19.3                   18.4                18.8
# 37                     21.3                   20.6                20.9
# 38                     23.5                   23.3                23.2
# 39                     24.2                   24.4                23.6
# 40                     18.3                   17.3                18.2
# 41                     21.9                   20.8                21.6
# 42                     19.6                   19.4                19.1
# 43                     20.6                   19.6                20.6
# 44                     20.4                   19.7                19.9
# 45                     24.1                   23.9                23.4
# 46                     23.9                   23.8                23.3
# 47                     22.2                   21.4                22.2
# 48                     20.3                   19.8                19.4
# 49                     20.5                   19.8                20.3
# 50                     20.0                   19.0                19.7
#
#     Average Reading Score  Average Science Score
# 0                    19.6                   19.0
# 1                    21.6                   20.7
# 2                    19.5                   19.2
# 3                    19.7                   19.4
# 4                    23.0                   22.1
# 5                    24.4                   23.5
# 6                    26.1                   24.9
# 7                    24.5                   23.4
# 8                    24.4                   23.0
# 9                    21.1                   19.5
# 10                   21.2                   21.4
# 11                   19.1                   19.0
# 12                   23.2                   22.1
# 13                   24.2                   23.4
# 14                   23.1                   22.2
# 15                   22.5                   22.0
# 16                   22.3                   21.5
# 17                   20.8                   20.1
# 18                   19.6                   19.1
# 19                   24.7                   23.4
# 20                   23.1                   22.2
# 21                   25.9                   24.7
# 22                   24.7                   23.9
# 23                   21.7                   21.4
# 24                   18.9                   18.6
# 25                   20.5                   20.0
# 26                   20.7                   20.0
# 27                   20.4                   20.1
# 28                   18.0                   17.9
# 29                   25.6                   24.4
# 30                   24.0                   23.0
# 31                   20.1                   19.7
# 32                   24.9                   24.2
# 33                   19.5                   19.2
# 34                   20.7                   20.5
# 35                   20.8                   20.4
# 36                   20.1                   19.4
# 37                   21.9                   21.1
# 38                   24.0                   23.1
# 39                   25.0                   23.5
# 40                   18.6                   18.5
# 41                   22.4                   22.2
# 42                   19.9                   19.6
# 43                   21.1                   20.8
# 44                   20.9                   20.5
# 45                   24.9                   23.8
# 46                   24.7                   23.5
# 47                   22.7                   22.0
# 48                   21.3                   20.4
# 49                   20.6                   20.8
# 50                   20.6                   20.3

# %%
sat_2018.head(52)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# 11                Hawaii           56%                                 480
# 12                 Idaho          100%                                 508
# 13              Illinois           99%                                 513
# 14               Indiana           63%                                 542
# 15                  Iowa            3%                                 634
# 16                Kansas            4%                                 633
# 17              Kentucky            4%                                 630
# 18             Louisiana            4%                                 615
# 19                 Maine           99%                                 512
# 20              Maryland           76%                                 545
# 21         Massachusetts           80%                                 562
# 22              Michigan          100%                                 511
# 23             Minnesota            4%                                 643
# 24           Mississippi            3%                                 630
# 25              Missouri            4%                                 633
# 26               Montana           10%                                 606
# 27              Nebraska            3%                                 629
# 28                Nevada           23%                                 574
# 29         New Hampshire           96%                                 535
# 30            New Jersey           82%                                 547
# 31            New Mexico           16%                                 552
# 32              New York           79%                                 534
# 33        North Carolina           52%                                 554
# 34          North Dakota            2%                                 640
# 35              Oklahoma            8%                                 541
# 36                  Ohio           18%                                 552
# 37                Oregon           48%                                 564
# 38          Pennsylvania           70%                                 547
# 39          Rhode Island           97%                                 513
# 40        South Carolina           55%                                 547
# 41          South Dakota            3%                                 622
# 42             Tennessee            6%                                 624
# 43                 Texas           66%                                 520
# 44                  Utah            4%                                 480
# 45               Vermont           64%                                 565
# 46              Virginia           68%                                 567
# 47            Washington           69%                                 543
# 48         West Virginia           28%                                 513
# 49             Wisconsin            3%                                 641
# 50               Wyoming            3%                                 633
#
#     Math  Total
# 0    571   1166
# 1    544   1106
# 2    572   1149
# 3    576   1169
# 4    536   1076
# 5    506   1025
# 6    519   1053
# 7    492    998
# 8    480    977
# 9    549   1099
# 10   522   1064
# 11   530   1010
# 12   493   1001
# 13   506   1019
# 14   532   1074
# 15   631   1265
# 16   631   1265
# 17   618   1248
# 18   595   1210
# 19   501   1013
# 20   535   1080
# 21   563   1125
# 22   499   1011
# 23   655   1298
# 24   606   1236
# 25   629   1262
# 26   592   1198
# 27   623   1252
# 28   566   1140
# 29   528   1063
# 30   547   1094
# 31   540   1093
# 32   534   1068
# 33   543   1098
# 34   643   1283
# 35   521   1062
# 36   547   1099
# 37   553   1117
# 38   539   1086
# 39   505   1018
# 40   523   1070
# 41   618   1240
# 42   607   1231
# 43   512   1032
# 44   530   1010
# 45   554   1120
# 46   550   1117
# 47   538   1081
# 48   486    999
# 49   653   1294
# 50   625   1257

# %%
act_2018.dtypes # we must change percentage of students and the other scores to float
# Out:
# State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
sat_2018.dtypes #we must convert participation, evidence , math ,total to float
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
#removing spaces with nothing , removing average to nothing and score to nothing.Also lowering case for column names

act_2018.columns=act_2018.columns.str.replace(' ','')
act_2018.columns=act_2018.columns.str.replace('average','')
act_2018.columns=act_2018.columns.str.replace('score','')
act_2018.columns =act_2018.columns.str.lower()

# %%
act_2018.head(10)
# Out:
#                   state  percentageofstudentstested  composite  english  math  \
# 0               Alabama                         100       19.1     18.9  18.3
# 1                Alaska                          33       20.8     19.8  20.6
# 2               Arizona                          66       19.2     18.2  19.4
# 3              Arkansas                         100       19.4     19.1  18.9
# 4            California                          27       22.7     22.5  22.5
# 5              Colorado                          30       23.9     23.9  23.2
# 6           Connecticut                          26       25.6     26.0  24.8
# 7              Delaware                          17       23.2     23.7  23.1
# 8  District of Columbia                          32       23.6     23.7  22.7
# 9               Florida                          66       19.9     19.2  19.3
#
#    reading  science
# 0     19.6     19.0
# 1     21.6     20.7
# 2     19.5     19.2
# 3     19.7     19.4
# 4     23.0     22.1
# 5     24.4     23.5
# 6     26.1     24.9
# 7     24.5     23.4
# 8     24.4     23.0
# 9     21.1     19.5

# %%
#change percentageofstudents to participation to be synonymous with the rest of data

act_2018.rename(columns={'percentageofstudentstested': 'participation',
                 },inplace = True)

# %%
act_2018.columns
# Out:
# Index(['state', 'participation', 'composite', 'english', 'math', 'reading',
#        'science'],
#       dtype='object')

# %%
#change values under participation rate to float values

act_2018['participation']=act_2018['participation'].apply(to_float)

# %%
act_2018.dtypes # checked  act_2018 data is cleaned and changed to float
# Out:
# state             object
# participation    float64
# composite        float64
# english          float64
# math             float64
# reading          float64
# science          float64
# dtype: object

# %%
act_2018.head(52) #check if 2018 is addded to all columns yes!
# Out:
#                    state  participation  composite  english  math  reading  \
# 0                Alabama          100.0       19.1     18.9  18.3     19.6
# 1                 Alaska           33.0       20.8     19.8  20.6     21.6
# 2                Arizona           66.0       19.2     18.2  19.4     19.5
# 3               Arkansas          100.0       19.4     19.1  18.9     19.7
# 4             California           27.0       22.7     22.5  22.5     23.0
# 5               Colorado           30.0       23.9     23.9  23.2     24.4
# 6            Connecticut           26.0       25.6     26.0  24.8     26.1
# 7               Delaware           17.0       23.2     23.7  23.1     24.5
# 8   District of Columbia           32.0       23.6     23.7  22.7     24.4
# 9                Florida           66.0       19.9     19.2  19.3     21.1
# 10               Georgia           53.0       21.4     20.9  20.7     21.2
# 11                Hawaii           89.0       18.9     18.2  19.0     19.1
# 12                 Idaho           36.0       22.3     21.9  21.6     23.2
# 13              Illinois           43.0       23.9     24.1  23.4     24.2
# 14               Indiana           32.0       22.5     21.9  22.3     23.1
# 15                  Iowa           68.0       21.8     21.0  21.2     22.5
# 16                Kansas           71.0       21.6     21.0  21.1     22.3
# 17              Kentucky          100.0       20.2     19.9  19.7     20.8
# 18             Louisiana          100.0       19.2     19.0  18.5     19.6
# 19                 Maine            7.0       24.0     23.8  23.6     24.7
# 20              Maryland           31.0       22.5     22.1  22.0     23.1
# 21         Massachusetts           25.0       25.5     25.5  25.2     25.9
# 22              Michigan           22.0       24.4     24.5  23.9     24.7
# 23             Minnesota           99.0       21.3     20.2  21.4     21.7
# 24           Mississippi          100.0       18.6     18.2  18.1     18.9
# 25              Missouri          100.0       20.0     19.5  19.7     20.5
# 26               Montana          100.0       20.0     18.7  19.9     20.7
# 27              Nebraska          100.0       20.1     19.4  19.8     20.4
# 28                Nevada          100.0       17.7     16.6  17.8     18.0
# 29         New Hampshire           16.0       25.1     25.1  24.7     25.6
# 30            New Jersey           31.0       23.7     23.8  23.6     24.0
# 31            New Mexico           67.0       19.4     18.3  19.1     20.1
# 32              New York           27.0       24.5     24.2  24.2     24.9
# 33        North Carolina          100.0       19.1     18.0  19.3     19.5
# 34          North Dakota           98.0       20.3     19.1  20.3     20.7
# 35                  Ohio          100.0       20.3     19.3  20.3     20.8
# 36              Oklahoma          100.0       19.3     18.4  18.8     20.1
# 37                Oregon           42.0       21.3     20.6  20.9     21.9
# 38          Pennsylvania           20.0       23.5     23.3  23.2     24.0
# 39          Rhode Island           15.0       24.2     24.4  23.6     25.0
# 40        South Carolina          100.0       18.3     17.3  18.2     18.6
# 41          South Dakota           77.0       21.9     20.8  21.6     22.4
# 42             Tennessee          100.0       19.6     19.4  19.1     19.9
# 43                 Texas           41.0       20.6     19.6  20.6     21.1
# 44                  Utah          100.0       20.4     19.7  19.9     20.9
# 45               Vermont           24.0       24.1     23.9  23.4     24.9
# 46              Virginia           24.0       23.9     23.8  23.3     24.7
# 47            Washington           24.0       22.2     21.4  22.2     22.7
# 48         West Virginia           65.0       20.3     19.8  19.4     21.3
# 49             Wisconsin          100.0       20.5     19.8  20.3     20.6
# 50               Wyoming          100.0       20.0     19.0  19.7     20.6
#
#     science
# 0      19.0
# 1      20.7
# 2      19.2
# 3      19.4
# 4      22.1
# 5      23.5
# 6      24.9
# 7      23.4
# 8      23.0
# 9      19.5
# 10     21.4
# 11     19.0
# 12     22.1
# 13     23.4
# 14     22.2
# 15     22.0
# 16     21.5
# 17     20.1
# 18     19.1
# 19     23.4
# 20     22.2
# 21     24.7
# 22     23.9
# 23     21.4
# 24     18.6
# 25     20.0
# 26     20.0
# 27     20.1
# 28     17.9
# 29     24.4
# 30     23.0
# 31     19.7
# 32     24.2
# 33     19.2
# 34     20.5
# 35     20.4
# 36     19.4
# 37     21.1
# 38     23.1
# 39     23.5
# 40     18.5
# 41     22.2
# 42     19.6
# 43     20.8
# 44     20.5
# 45     23.8
# 46     23.5
# 47     22.0
# 48     20.4
# 49     20.8
# 50     20.3

# %%
act_2018.columns=[n+'_act_2018' for n in act_2018.columns]

# %%
sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# 8   480    977
# 9   549   1099

# %%
#Remove the % values under participation str so we can convert it to float
sat_2018['Participation'] = sat_2018['Participation'].str.replace ('%', '')

# %%
sat_2018['Participation']= sat_2018['Participation'].apply(to_float)
sat_2018['Evidence-Based Reading and Writing']= sat_2018['Evidence-Based Reading and Writing'].apply(to_float)
sat_2018['Math']=sat_2018['Math'].apply(to_float)
sat_2018['Total']=sat_2018['Total'].apply(to_float) # we converting all the sat_2018 types to float

# %%
sat_2018.columns =sat_2018.columns.str.lower()# converting all columns of sat_2018 to lower

# %%
sat_2018.columns=[n+'_sat_2018' for n in sat_2018.columns]

# %%
sat_2018.head(10) #check if all are converted.
# Out:
#          state_sat_2018  participation_sat_2018  \
# 0               Alabama                     6.0
# 1                Alaska                    43.0
# 2               Arizona                    29.0
# 3              Arkansas                     5.0
# 4            California                    60.0
# 5              Colorado                   100.0
# 6           Connecticut                   100.0
# 7              Delaware                   100.0
# 8  District of Columbia                    92.0
# 9               Florida                    56.0
#
#    evidence-based reading and writing_sat_2018  math_sat_2018  total_sat_2018
# 0                                        595.0          571.0          1166.0
# 1                                        562.0          544.0          1106.0
# 2                                        577.0          572.0          1149.0
# 3                                        592.0          576.0          1169.0
# 4                                        540.0          536.0          1076.0
# 5                                        519.0          506.0          1025.0
# 6                                        535.0          519.0          1053.0
# 7                                        505.0          492.0           998.0
# 8                                        497.0          480.0           977.0
# 9                                        550.0          549.0          1099.0

# %%
#rename sat208 column for evidence based reading and writing to composite
sat_2018.rename(columns={
    'evidence-based reading and writing_sat_2018' :'composite_sat_2018',
},inplace= True)

# %%
#rename sat 2017 column for evidence based and writing to composite
sat_2017.rename(columns={
    'evidence-based_reading_and_writing_sat_2017' :'composite_sat_2017',
},inplace= True)

# %%
act_2018
# Out:
#           state_act_2018  participation_act_2018  composite_act_2018  \
# 0                Alabama                   100.0                19.1
# 1                 Alaska                    33.0                20.8
# 2                Arizona                    66.0                19.2
# 3               Arkansas                   100.0                19.4
# 4             California                    27.0                22.7
# 5               Colorado                    30.0                23.9
# 6            Connecticut                    26.0                25.6
# 7               Delaware                    17.0                23.2
# 8   District of Columbia                    32.0                23.6
# 9                Florida                    66.0                19.9
# 10               Georgia                    53.0                21.4
# 11                Hawaii                    89.0                18.9
# 12                 Idaho                    36.0                22.3
# 13              Illinois                    43.0                23.9
# 14               Indiana                    32.0                22.5
# 15                  Iowa                    68.0                21.8
# 16                Kansas                    71.0                21.6
# 17              Kentucky                   100.0                20.2
# 18             Louisiana                   100.0                19.2
# 19                 Maine                     7.0                24.0
# 20              Maryland                    31.0                22.5
# 21         Massachusetts                    25.0                25.5
# 22              Michigan                    22.0                24.4
# 23             Minnesota                    99.0                21.3
# 24           Mississippi                   100.0                18.6
# 25              Missouri                   100.0                20.0
# 26               Montana                   100.0                20.0
# 27              Nebraska                   100.0                20.1
# 28                Nevada                   100.0                17.7
# 29         New Hampshire                    16.0                25.1
# 30            New Jersey                    31.0                23.7
# 31            New Mexico                    67.0                19.4
# 32              New York                    27.0                24.5
# 33        North Carolina                   100.0                19.1
# 34          North Dakota                    98.0                20.3
# 35                  Ohio                   100.0                20.3
# 36              Oklahoma                   100.0                19.3
# 37                Oregon                    42.0                21.3
# 38          Pennsylvania                    20.0                23.5
# 39          Rhode Island                    15.0                24.2
# 40        South Carolina                   100.0                18.3
# 41          South Dakota                    77.0                21.9
# 42             Tennessee                   100.0                19.6
# 43                 Texas                    41.0                20.6
# 44                  Utah                   100.0                20.4
# 45               Vermont                    24.0                24.1
# 46              Virginia                    24.0                23.9
# 47            Washington                    24.0                22.2
# 48         West Virginia                    65.0                20.3
# 49             Wisconsin                   100.0                20.5
# 50               Wyoming                   100.0                20.0
#
#     english_act_2018  math_act_2018  reading_act_2018  science_act_2018
# 0               18.9           18.3              19.6              19.0
# 1               19.8           20.6              21.6              20.7
# 2               18.2           19.4              19.5              19.2
# 3               19.1           18.9              19.7              19.4
# 4               22.5           22.5              23.0              22.1
# 5               23.9           23.2              24.4              23.5
# 6               26.0           24.8              26.1              24.9
# 7               23.7           23.1              24.5              23.4
# 8               23.7           22.7              24.4              23.0
# 9               19.2           19.3              21.1              19.5
# 10              20.9           20.7              21.2              21.4
# 11              18.2           19.0              19.1              19.0
# 12              21.9           21.6              23.2              22.1
# 13              24.1           23.4              24.2              23.4
# 14              21.9           22.3              23.1              22.2
# 15              21.0           21.2              22.5              22.0
# 16              21.0           21.1              22.3              21.5
# 17              19.9           19.7              20.8              20.1
# 18              19.0           18.5              19.6              19.1
# 19              23.8           23.6              24.7              23.4
# 20              22.1           22.0              23.1              22.2
# 21              25.5           25.2              25.9              24.7
# 22              24.5           23.9              24.7              23.9
# 23              20.2           21.4              21.7              21.4
# 24              18.2           18.1              18.9              18.6
# 25              19.5           19.7              20.5              20.0
# 26              18.7           19.9              20.7              20.0
# 27              19.4           19.8              20.4              20.1
# 28              16.6           17.8              18.0              17.9
# 29              25.1           24.7              25.6              24.4
# 30              23.8           23.6              24.0              23.0
# 31              18.3           19.1              20.1              19.7
# 32              24.2           24.2              24.9              24.2
# 33              18.0           19.3              19.5              19.2
# 34              19.1           20.3              20.7              20.5
# 35              19.3           20.3              20.8              20.4
# 36              18.4           18.8              20.1              19.4
# 37              20.6           20.9              21.9              21.1
# 38              23.3           23.2              24.0              23.1
# 39              24.4           23.6              25.0              23.5
# 40              17.3           18.2              18.6              18.5
# 41              20.8           21.6              22.4              22.2
# 42              19.4           19.1              19.9              19.6
# 43              19.6           20.6              21.1              20.8
# 44              19.7           19.9              20.9              20.5
# 45              23.9           23.4              24.9              23.8
# 46              23.8           23.3              24.7              23.5
# 47              21.4           22.2              22.7              22.0
# 48              19.8           19.4              21.3              20.4
# 49              19.8           20.3              20.6              20.8
# 50              19.0           19.7              20.6              20.3

# %%
#merging act and sat2018 dataframes
combined_2018 = pd.merge(sat_2018,act_2018, left_on= 'state_sat_2018', right_on ='state_act_2018', how ='outer')

# %%
combined_2018
# Out:
#           state_sat_2018  participation_sat_2018  composite_sat_2018  \
# 0                Alabama                     6.0               595.0
# 1                 Alaska                    43.0               562.0
# 2                Arizona                    29.0               577.0
# 3               Arkansas                     5.0               592.0
# 4             California                    60.0               540.0
# 5               Colorado                   100.0               519.0
# 6            Connecticut                   100.0               535.0
# 7               Delaware                   100.0               505.0
# 8   District of Columbia                    92.0               497.0
# 9                Florida                    56.0               550.0
# 10               Georgia                    70.0               542.0
# 11                Hawaii                    56.0               480.0
# 12                 Idaho                   100.0               508.0
# 13              Illinois                    99.0               513.0
# 14               Indiana                    63.0               542.0
# 15                  Iowa                     3.0               634.0
# 16                Kansas                     4.0               633.0
# 17              Kentucky                     4.0               630.0
# 18             Louisiana                     4.0               615.0
# 19                 Maine                    99.0               512.0
# 20              Maryland                    76.0               545.0
# 21         Massachusetts                    80.0               562.0
# 22              Michigan                   100.0               511.0
# 23             Minnesota                     4.0               643.0
# 24           Mississippi                     3.0               630.0
# 25              Missouri                     4.0               633.0
# 26               Montana                    10.0               606.0
# 27              Nebraska                     3.0               629.0
# 28                Nevada                    23.0               574.0
# 29         New Hampshire                    96.0               535.0
# 30            New Jersey                    82.0               547.0
# 31            New Mexico                    16.0               552.0
# 32              New York                    79.0               534.0
# 33        North Carolina                    52.0               554.0
# 34          North Dakota                     2.0               640.0
# 35              Oklahoma                     8.0               541.0
# 36                  Ohio                    18.0               552.0
# 37                Oregon                    48.0               564.0
# 38          Pennsylvania                    70.0               547.0
# 39          Rhode Island                    97.0               513.0
# 40        South Carolina                    55.0               547.0
# 41          South Dakota                     3.0               622.0
# 42             Tennessee                     6.0               624.0
# 43                 Texas                    66.0               520.0
# 44                  Utah                     4.0               480.0
# 45               Vermont                    64.0               565.0
# 46              Virginia                    68.0               567.0
# 47            Washington                    69.0               543.0
# 48         West Virginia                    28.0               513.0
# 49             Wisconsin                     3.0               641.0
# 50               Wyoming                     3.0               633.0
#
#     math_sat_2018  total_sat_2018        state_act_2018  \
# 0           571.0          1166.0               Alabama
# 1           544.0          1106.0                Alaska
# 2           572.0          1149.0               Arizona
# 3           576.0          1169.0              Arkansas
# 4           536.0          1076.0            California
# 5           506.0          1025.0              Colorado
# 6           519.0          1053.0           Connecticut
# 7           492.0           998.0              Delaware
# 8           480.0           977.0  District of Columbia
# 9           549.0          1099.0               Florida
# 10          522.0          1064.0               Georgia
# 11          530.0          1010.0                Hawaii
# 12          493.0          1001.0                 Idaho
# 13          506.0          1019.0              Illinois
# 14          532.0          1074.0               Indiana
# 15          631.0          1265.0                  Iowa
# 16          631.0          1265.0                Kansas
# 17          618.0          1248.0              Kentucky
# 18          595.0          1210.0             Louisiana
# 19          501.0          1013.0                 Maine
# 20          535.0          1080.0              Maryland
# 21          563.0          1125.0         Massachusetts
# 22          499.0          1011.0              Michigan
# 23          655.0          1298.0             Minnesota
# 24          606.0          1236.0           Mississippi
# 25          629.0          1262.0              Missouri
# 26          592.0          1198.0               Montana
# 27          623.0          1252.0              Nebraska
# 28          566.0          1140.0                Nevada
# 29          528.0          1063.0         New Hampshire
# 30          547.0          1094.0            New Jersey
# 31          540.0          1093.0            New Mexico
# 32          534.0          1068.0              New York
# 33          543.0          1098.0        North Carolina
# 34          643.0          1283.0          North Dakota
# 35          521.0          1062.0              Oklahoma
# 36          547.0          1099.0                  Ohio
# 37          553.0          1117.0                Oregon
# 38          539.0          1086.0          Pennsylvania
# 39          505.0          1018.0          Rhode Island
# 40          523.0          1070.0        South Carolina
# 41          618.0          1240.0          South Dakota
# 42          607.0          1231.0             Tennessee
# 43          512.0          1032.0                 Texas
# 44          530.0          1010.0                  Utah
# 45          554.0          1120.0               Vermont
# 46          550.0          1117.0              Virginia
# 47          538.0          1081.0            Washington
# 48          486.0           999.0         West Virginia
# 49          653.0          1294.0             Wisconsin
# 50          625.0          1257.0               Wyoming
#
#     participation_act_2018  composite_act_2018  english_act_2018  \
# 0                    100.0                19.1              18.9
# 1                     33.0                20.8              19.8
# 2                     66.0                19.2              18.2
# 3                    100.0                19.4              19.1
# 4                     27.0                22.7              22.5
# 5                     30.0                23.9              23.9
# 6                     26.0                25.6              26.0
# 7                     17.0                23.2              23.7
# 8                     32.0                23.6              23.7
# 9                     66.0                19.9              19.2
# 10                    53.0                21.4              20.9
# 11                    89.0                18.9              18.2
# 12                    36.0                22.3              21.9
# 13                    43.0                23.9              24.1
# 14                    32.0                22.5              21.9
# 15                    68.0                21.8              21.0
# 16                    71.0                21.6              21.0
# 17                   100.0                20.2              19.9
# 18                   100.0                19.2              19.0
# 19                     7.0                24.0              23.8
# 20                    31.0                22.5              22.1
# 21                    25.0                25.5              25.5
# 22                    22.0                24.4              24.5
# 23                    99.0                21.3              20.2
# 24                   100.0                18.6              18.2
# 25                   100.0                20.0              19.5
# 26                   100.0                20.0              18.7
# 27                   100.0                20.1              19.4
# 28                   100.0                17.7              16.6
# 29                    16.0                25.1              25.1
# 30                    31.0                23.7              23.8
# 31                    67.0                19.4              18.3
# 32                    27.0                24.5              24.2
# 33                   100.0                19.1              18.0
# 34                    98.0                20.3              19.1
# 35                   100.0                19.3              18.4
# 36                   100.0                20.3              19.3
# 37                    42.0                21.3              20.6
# 38                    20.0                23.5              23.3
# 39                    15.0                24.2              24.4
# 40                   100.0                18.3              17.3
# 41                    77.0                21.9              20.8
# 42                   100.0                19.6              19.4
# 43                    41.0                20.6              19.6
# 44                   100.0                20.4              19.7
# 45                    24.0                24.1              23.9
# 46                    24.0                23.9              23.8
# 47                    24.0                22.2              21.4
# 48                    65.0                20.3              19.8
# 49                   100.0                20.5              19.8
# 50                   100.0                20.0              19.0
#
#     math_act_2018  reading_act_2018  science_act_2018
# 0            18.3              19.6              19.0
# 1            20.6              21.6              20.7
# 2            19.4              19.5              19.2
# 3            18.9              19.7              19.4
# 4            22.5              23.0              22.1
# 5            23.2              24.4              23.5
# 6            24.8              26.1              24.9
# 7            23.1              24.5              23.4
# 8            22.7              24.4              23.0
# 9            19.3              21.1              19.5
# 10           20.7              21.2              21.4
# 11           19.0              19.1              19.0
# 12           21.6              23.2              22.1
# 13           23.4              24.2              23.4
# 14           22.3              23.1              22.2
# 15           21.2              22.5              22.0
# 16           21.1              22.3              21.5
# 17           19.7              20.8              20.1
# 18           18.5              19.6              19.1
# 19           23.6              24.7              23.4
# 20           22.0              23.1              22.2
# 21           25.2              25.9              24.7
# 22           23.9              24.7              23.9
# 23           21.4              21.7              21.4
# 24           18.1              18.9              18.6
# 25           19.7              20.5              20.0
# 26           19.9              20.7              20.0
# 27           19.8              20.4              20.1
# 28           17.8              18.0              17.9
# 29           24.7              25.6              24.4
# 30           23.6              24.0              23.0
# 31           19.1              20.1              19.7
# 32           24.2              24.9              24.2
# 33           19.3              19.5              19.2
# 34           20.3              20.7              20.5
# 35           18.8              20.1              19.4
# 36           20.3              20.8              20.4
# 37           20.9              21.9              21.1
# 38           23.2              24.0              23.1
# 39           23.6              25.0              23.5
# 40           18.2              18.6              18.5
# 41           21.6              22.4              22.2
# 42           19.1              19.9              19.6
# 43           20.6              21.1              20.8
# 44           19.9              20.9              20.5
# 45           23.4              24.9              23.8
# 46           23.3              24.7              23.5
# 47           22.2              22.7              22.0
# 48           19.4              21.3              20.4
# 49           20.3              20.6              20.8
# 50           19.7              20.6              20.3

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
merged_final = pd.merge(combined_2017,combined_2018, left_on = 'state_sat_2017', right_on='state_act_2018', how ='outer')

# %%
merged_final
# Out:
#           state_sat_2017  participation_sat_2017  \
# 0                Alabama                     5.0
# 1                 Alaska                    38.0
# 2                Arizona                    30.0
# 3               Arkansas                     3.0
# 4             California                    53.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 9                Florida                    83.0
# 10               Georgia                    61.0
# 11                Hawaii                    55.0
# 12                 Idaho                    93.0
# 13              Illinois                     9.0
# 14               Indiana                    63.0
# 15                  Iowa                     2.0
# 16                Kansas                     4.0
# 17              Kentucky                     4.0
# 18             Louisiana                     4.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
# 21         Massachusetts                    76.0
# 22              Michigan                   100.0
# 23             Minnesota                     3.0
# 24           Mississippi                     2.0
# 25              Missouri                     3.0
# 26               Montana                    10.0
# 27              Nebraska                     3.0
# 28                Nevada                    26.0
# 29         New Hampshire                    96.0
# 30            New Jersey                    70.0
# 31            New Mexico                    11.0
# 32              New York                    67.0
# 33        North Carolina                    49.0
# 34          North Dakota                     2.0
# 35                  Ohio                    12.0
# 36              Oklahoma                     7.0
# 37                Oregon                    43.0
# 38          Pennsylvania                    65.0
# 39          Rhode Island                    71.0
# 40        South Carolina                    50.0
# 41          South Dakota                     3.0
# 42             Tennessee                     5.0
# 43                 Texas                    62.0
# 44                  Utah                     3.0
# 45               Vermont                    60.0
# 46              Virginia                    65.0
# 47            Washington                    64.0
# 48         West Virginia                    14.0
# 49             Wisconsin                     3.0
# 50               Wyoming                     3.0
#
#     evidence-based_reading_and_writing_sat_2017  math_sat_2017  \
# 0                                         593.0          572.0
# 1                                         547.0          533.0
# 2                                         563.0          553.0
# 3                                         614.0          594.0
# 4                                         531.0          524.0
# 5                                         606.0          595.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# 8                                         482.0          468.0
# 9                                         520.0          497.0
# 10                                        535.0          515.0
# 11                                        544.0          541.0
# 12                                        513.0          493.0
# 13                                        559.0          556.0
# 14                                        542.0          532.0
# 15                                        641.0          635.0
# 16                                        632.0          628.0
# 17                                        631.0          616.0
# 18                                        611.0          586.0
# 19                                        513.0          499.0
# 20                                        536.0          524.0
# 21                                        555.0          551.0
# 22                                        509.0          495.0
# 23                                        644.0          651.0
# 24                                        634.0          607.0
# 25                                        640.0          631.0
# 26                                        605.0          591.0
# 27                                        629.0          625.0
# 28                                        563.0          553.0
# 29                                        532.0          520.0
# 30                                        530.0          526.0
# 31                                        577.0          561.0
# 32                                        528.0          523.0
# 33                                        546.0          535.0
# 34                                        635.0          621.0
# 35                                        578.0          570.0
# 36                                        530.0          517.0
# 37                                        560.0          548.0
# 38                                        540.0          531.0
# 39                                        539.0          524.0
# 40                                        543.0          521.0
# 41                                        612.0          603.0
# 42                                        623.0          604.0
# 43                                        513.0          507.0
# 44                                        624.0          614.0
# 45                                        562.0          551.0
# 46                                        561.0          541.0
# 47                                        541.0          534.0
# 48                                        558.0          528.0
# 49                                        642.0          649.0
# 50                                        626.0          604.0
#
#     total_sat_2017        state_act_2017  participation_act_2017  \
# 0           1165.0               Alabama                   100.0
# 1           1080.0                Alaska                    65.0
# 2           1116.0               Arizona                    62.0
# 3           1208.0              Arkansas                   100.0
# 4           1055.0            California                    31.0
# 5           1201.0              Colorado                   100.0
# 6           1041.0           Connecticut                    31.0
# 7            996.0              Delaware                    18.0
# 8            950.0  District of Columbia                    32.0
# 9           1017.0               Florida                    73.0
# 10          1050.0               Georgia                    55.0
# 11          1085.0                Hawaii                    90.0
# 12          1005.0                 Idaho                    38.0
# 13          1115.0              Illinois                    93.0
# 14          1074.0               Indiana                    35.0
# 15          1275.0                  Iowa                    67.0
# 16          1260.0                Kansas                    73.0
# 17          1247.0              Kentucky                   100.0
# 18          1198.0             Louisiana                   100.0
# 19          1012.0                 Maine                     8.0
# 20          1060.0              Maryland                    28.0
# 21          1107.0         Massachusetts                    29.0
# 22          1005.0              Michigan                    29.0
# 23          1295.0             Minnesota                   100.0
# 24          1242.0           Mississippi                   100.0
# 25          1271.0              Missouri                   100.0
# 26          1196.0               Montana                   100.0
# 27          1253.0              Nebraska                    84.0
# 28          1116.0                Nevada                   100.0
# 29          1052.0         New Hampshire                    18.0
# 30          1056.0            New Jersey                    34.0
# 31          1138.0            New Mexico                    66.0
# 32          1052.0              New York                    31.0
# 33          1081.0        North Carolina                   100.0
# 34          1256.0          North Dakota                    98.0
# 35          1149.0                  Ohio                    75.0
# 36          1047.0              Oklahoma                   100.0
# 37          1108.0                Oregon                    40.0
# 38          1071.0          Pennsylvania                    23.0
# 39          1062.0          Rhode Island                    21.0
# 40          1064.0        South Carolina                   100.0
# 41          1216.0          South Dakota                    80.0
# 42          1228.0             Tennessee                   100.0
# 43          1020.0                 Texas                    45.0
# 44          1238.0                  Utah                   100.0
# 45          1114.0               Vermont                    29.0
# 46          1102.0              Virginia                    29.0
# 47          1075.0            Washington                    29.0
# 48          1086.0         West Virginia                    69.0
# 49          1291.0             Wisconsin                   100.0
# 50          1230.0               Wyoming                   100.0
#
#     english_act_2017  math_act_2017  reading_act_2017  ...  \
# 0               18.9           18.4              19.7  ...
# 1               18.7           19.8              20.4  ...
# 2               18.6           19.8              20.1  ...
# 3               18.9           19.0              19.7  ...
# 4               22.5           22.7              23.1  ...
# 5               20.1           20.3              21.2  ...
# 6               25.5           24.6              25.6  ...
# 7               24.1           23.4              24.8  ...
# 8               24.4           23.5              24.9  ...
# 9               19.0           19.4              21.0  ...
# 10              21.0           20.9              22.0  ...
# 11              17.8           19.2              19.2  ...
# 12              21.9           21.8              23.0  ...
# 13              21.0           21.2              21.6  ...
# 14              22.0           22.4              23.2  ...
# 15              21.2           21.3              22.6  ...
# 16              21.1           21.3              22.3  ...
# 17              19.6           19.4              20.5  ...
# 18              19.4           18.8              19.8  ...
# 19              24.2           24.0              24.8  ...
# 20              23.3           23.1              24.2  ...
# 21              25.4           25.3              25.9  ...
# 22              24.1           23.7              24.5  ...
# 23              20.4           21.5              21.8  ...
# 24              18.2           18.1              18.8  ...
# 25              19.8           19.9              20.8  ...
# 26              19.0           20.2              21.0  ...
# 27              20.9           20.9              21.9  ...
# 28              16.3           18.0              18.1  ...
# 29              25.4           25.1              26.0  ...
# 30              23.8           23.8              24.1  ...
# 31              18.6           19.4              20.4  ...
# 32              23.8           24.0              24.6  ...
# 33              17.8           19.3              19.6  ...
# 34              19.0           20.4              20.5  ...
# 35              21.2           21.6              22.5  ...
# 36              18.5           18.8              20.1  ...
# 37              21.2           21.5              22.4  ...
# 38              23.4           23.4              24.2  ...
# 39              24.0           23.3              24.7  ...
# 40              17.5           18.6              19.1  ...
# 41              20.7           21.5              22.3  ...
# 42              19.5           19.2              20.1  ...
# 43              19.5           20.7              21.1  ...
# 44              19.5           19.9              20.8  ...
# 45              23.3           23.1              24.4  ...
# 46              23.5           23.3              24.6  ...
# 47              20.9           21.9              22.1  ...
# 48              20.0           19.4              21.2  ...
# 49              19.7           20.4              20.6  ...
# 50              19.4           19.8              20.8  ...
#
#     composite_sat_2018  math_sat_2018 total_sat_2018        state_act_2018  \
# 0                595.0          571.0         1166.0               Alabama
# 1                562.0          544.0         1106.0                Alaska
# 2                577.0          572.0         1149.0               Arizona
# 3                592.0          576.0         1169.0              Arkansas
# 4                540.0          536.0         1076.0            California
# 5                519.0          506.0         1025.0              Colorado
# 6                535.0          519.0         1053.0           Connecticut
# 7                505.0          492.0          998.0              Delaware
# 8                497.0          480.0          977.0  District of Columbia
# 9                550.0          549.0         1099.0               Florida
# 10               542.0          522.0         1064.0               Georgia
# 11               480.0          530.0         1010.0                Hawaii
# 12               508.0          493.0         1001.0                 Idaho
# 13               513.0          506.0         1019.0              Illinois
# 14               542.0          532.0         1074.0               Indiana
# 15               634.0          631.0         1265.0                  Iowa
# 16               633.0          631.0         1265.0                Kansas
# 17               630.0          618.0         1248.0              Kentucky
# 18               615.0          595.0         1210.0             Louisiana
# 19               512.0          501.0         1013.0                 Maine
# 20               545.0          535.0         1080.0              Maryland
# 21               562.0          563.0         1125.0         Massachusetts
# 22               511.0          499.0         1011.0              Michigan
# 23               643.0          655.0         1298.0             Minnesota
# 24               630.0          606.0         1236.0           Mississippi
# 25               633.0          629.0         1262.0              Missouri
# 26               606.0          592.0         1198.0               Montana
# 27               629.0          623.0         1252.0              Nebraska
# 28               574.0          566.0         1140.0                Nevada
# 29               535.0          528.0         1063.0         New Hampshire
# 30               547.0          547.0         1094.0            New Jersey
# 31               552.0          540.0         1093.0            New Mexico
# 32               534.0          534.0         1068.0              New York
# 33               554.0          543.0         1098.0        North Carolina
# 34               640.0          643.0         1283.0          North Dakota
# 35               552.0          547.0         1099.0                  Ohio
# 36               541.0          521.0         1062.0              Oklahoma
# 37               564.0          553.0         1117.0                Oregon
# 38               547.0          539.0         1086.0          Pennsylvania
# 39               513.0          505.0         1018.0          Rhode Island
# 40               547.0          523.0         1070.0        South Carolina
# 41               622.0          618.0         1240.0          South Dakota
# 42               624.0          607.0         1231.0             Tennessee
# 43               520.0          512.0         1032.0                 Texas
# 44               480.0          530.0         1010.0                  Utah
# 45               565.0          554.0         1120.0               Vermont
# 46               567.0          550.0         1117.0              Virginia
# 47               543.0          538.0         1081.0            Washington
# 48               513.0          486.0          999.0         West Virginia
# 49               641.0          653.0         1294.0             Wisconsin
# 50               633.0          625.0         1257.0               Wyoming
#
#     participation_act_2018  composite_act_2018  english_act_2018  \
# 0                    100.0                19.1              18.9
# 1                     33.0                20.8              19.8
# 2                     66.0                19.2              18.2
# 3                    100.0                19.4              19.1
# 4                     27.0                22.7              22.5
# 5                     30.0                23.9              23.9
# 6                     26.0                25.6              26.0
# 7                     17.0                23.2              23.7
# 8                     32.0                23.6              23.7
# 9                     66.0                19.9              19.2
# 10                    53.0                21.4              20.9
# 11                    89.0                18.9              18.2
# 12                    36.0                22.3              21.9
# 13                    43.0                23.9              24.1
# 14                    32.0                22.5              21.9
# 15                    68.0                21.8              21.0
# 16                    71.0                21.6              21.0
# 17                   100.0                20.2              19.9
# 18                   100.0                19.2              19.0
# 19                     7.0                24.0              23.8
# 20                    31.0                22.5              22.1
# 21                    25.0                25.5              25.5
# 22                    22.0                24.4              24.5
# 23                    99.0                21.3              20.2
# 24                   100.0                18.6              18.2
# 25                   100.0                20.0              19.5
# 26                   100.0                20.0              18.7
# 27                   100.0                20.1              19.4
# 28                   100.0                17.7              16.6
# 29                    16.0                25.1              25.1
# 30                    31.0                23.7              23.8
# 31                    67.0                19.4              18.3
# 32                    27.0                24.5              24.2
# 33                   100.0                19.1              18.0
# 34                    98.0                20.3              19.1
# 35                   100.0                20.3              19.3
# 36                   100.0                19.3              18.4
# 37                    42.0                21.3              20.6
# 38                    20.0                23.5              23.3
# 39                    15.0                24.2              24.4
# 40                   100.0                18.3              17.3
# 41                    77.0                21.9              20.8
# 42                   100.0                19.6              19.4
# 43                    41.0                20.6              19.6
# 44                   100.0                20.4              19.7
# 45                    24.0                24.1              23.9
# 46                    24.0                23.9              23.8
# 47                    24.0                22.2              21.4
# 48                    65.0                20.3              19.8
# 49                   100.0                20.5              19.8
# 50                   100.0                20.0              19.0
#
#    math_act_2018  reading_act_2018  science_act_2018
# 0           18.3              19.6              19.0
# 1           20.6              21.6              20.7
# 2           19.4              19.5              19.2
# 3           18.9              19.7              19.4
# 4           22.5              23.0              22.1
# 5           23.2              24.4              23.5
# 6           24.8              26.1              24.9
# 7           23.1              24.5              23.4
# 8           22.7              24.4              23.0
# 9           19.3              21.1              19.5
# 10          20.7              21.2              21.4
# 11          19.0              19.1              19.0
# 12          21.6              23.2              22.1
# 13          23.4              24.2              23.4
# 14          22.3              23.1              22.2
# 15          21.2              22.5              22.0
# 16          21.1              22.3              21.5
# 17          19.7              20.8              20.1
# 18          18.5              19.6              19.1
# 19          23.6              24.7              23.4
# 20          22.0              23.1              22.2
# 21          25.2              25.9              24.7
# 22          23.9              24.7              23.9
# 23          21.4              21.7              21.4
# 24          18.1              18.9              18.6
# 25          19.7              20.5              20.0
# 26          19.9              20.7              20.0
# 27          19.8              20.4              20.1
# 28          17.8              18.0              17.9
# 29          24.7              25.6              24.4
# 30          23.6              24.0              23.0
# 31          19.1              20.1              19.7
# 32          24.2              24.9              24.2
# 33          19.3              19.5              19.2
# 34          20.3              20.7              20.5
# 35          20.3              20.8              20.4
# 36          18.8              20.1              19.4
# 37          20.9              21.9              21.1
# 38          23.2              24.0              23.1
# 39          23.6              25.0              23.5
# 40          18.2              18.6              18.5
# 41          21.6              22.4              22.2
# 42          19.1              19.9              19.6
# 43          20.6              21.1              20.8
# 44          19.9              20.9              20.5
# 45          23.4              24.9              23.8
# 46          23.3              24.7              23.5
# 47          22.2              22.7              22.0
# 48          19.4              21.3              20.4
# 49          20.3              20.6              20.8
# 50          19.7              20.6              20.3
#
# [51 rows x 24 columns]

# %%
merged_final.to_csv('final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code applying the describe function on merged_final ,data frame is rounded to two decimal places and transposed to view it better
round(merged_final.describe(),2).T
# Out:
#                                              count     mean    std    min  \
# participation_sat_2017                        51.0    39.80  35.28    2.0
# evidence-based_reading_and_writing_sat_2017   51.0   569.12  45.67  482.0
# math_sat_2017                                 51.0   556.88  47.12  468.0
# total_sat_2017                                51.0  1126.10  92.49  950.0
# participation_act_2017                        51.0    65.25  32.14    8.0
# english_act_2017                              51.0    20.93   2.35   16.3
# math_act_2017                                 51.0    21.18   1.98   18.0
# reading_act_2017                              51.0    22.01   2.07   18.1
# science_act_2017                              51.0    21.45   1.74   18.2
# composite_act_2017                            51.0    21.52   2.02   17.8
# participation_sat_2018                        51.0    45.75  37.31    2.0
# composite_sat_2018                            51.0   563.69  47.50  480.0
# math_sat_2018                                 51.0   556.24  47.77  480.0
# total_sat_2018                                51.0  1120.02  94.16  977.0
# participation_act_2018                        51.0    61.65  34.08    7.0
# composite_act_2018                            51.0    21.49   2.11   17.7
# english_act_2018                              51.0    20.99   2.45   16.6
# math_act_2018                                 51.0    21.13   2.04   17.8
# reading_act_2018                              51.0    22.02   2.17   18.0
# science_act_2018                              51.0    21.35   1.87   17.9
#
#                                                  25%     50%      75%     max
# participation_sat_2017                          4.00    38.0    66.00   100.0
# evidence-based_reading_and_writing_sat_2017   533.50   559.0   613.00   644.0
# math_sat_2017                                 523.50   548.0   599.00   651.0
# total_sat_2017                               1055.50  1107.0  1212.00  1295.0
# participation_act_2017                         31.00    69.0   100.00   100.0
# english_act_2017                               19.00    20.7    23.30    25.5
# math_act_2017                                  19.40    20.9    23.10    25.3
# reading_act_2017                               20.45    21.8    24.15    26.0
# science_act_2017                               19.95    21.3    23.20    24.9
# composite_act_2017                             19.80    21.4    23.60    25.5
# participation_sat_2018                          4.50    52.0    77.50   100.0
# composite_sat_2018                            534.50   552.0   610.50   643.0
# math_sat_2018                                 522.50   544.0   593.50   655.0
# total_sat_2018                               1057.50  1098.0  1204.00  1298.0
# participation_act_2018                         28.50    66.0   100.00   100.0
# composite_act_2018                             19.95    21.3    23.55    25.6
# english_act_2018                               19.10    20.2    23.70    26.0
# math_act_2018                                  19.40    20.7    23.15    25.2
# reading_act_2018                               20.45    21.6    24.10    26.1
# science_act_2018                               19.85    21.1    23.05    24.9

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#declaring function to sigma to calculate standard deviation
def to_sigma(dataseries):
    n= dataseries.count()
    mew = dataseries.mean()
    summed =0
    for i in dataseries:
        summed +=(i - mew)**2
    return(np.sqrt(summed/(n)))

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code: utilizing dictionary comprehension to apply standard deviation to dataframe merged_final
sd = {column:to_sigma(merged_final[column]) for column in merged_final if 'state' not in column}

# %%
merged_final.describe()
# Out:
#        participation_sat_2017  evidence-based_reading_and_writing_sat_2017  \
# count               51.000000                                    51.000000
# mean                39.803922                                   569.117647
# std                 35.276632                                    45.666901
# min                  2.000000                                   482.000000
# 25%                  4.000000                                   533.500000
# 50%                 38.000000                                   559.000000
# 75%                 66.000000                                   613.000000
# max                100.000000                                   644.000000
#
#        math_sat_2017  total_sat_2017  participation_act_2017  \
# count      51.000000       51.000000               51.000000
# mean      556.882353     1126.098039               65.254902
# std        47.121395       92.494812               32.140842
# min       468.000000      950.000000                8.000000
# 25%       523.500000     1055.500000               31.000000
# 50%       548.000000     1107.000000               69.000000
# 75%       599.000000     1212.000000              100.000000
# max       651.000000     1295.000000              100.000000
#
#        english_act_2017  math_act_2017  reading_act_2017  science_act_2017  \
# count         51.000000      51.000000         51.000000         51.000000
# mean          20.931373      21.182353         22.013725         21.450980
# std            2.353677       1.981989          2.067271          1.739353
# min           16.300000      18.000000         18.100000         18.200000
# 25%           19.000000      19.400000         20.450000         19.950000
# 50%           20.700000      20.900000         21.800000         21.300000
# 75%           23.300000      23.100000         24.150000         23.200000
# max           25.500000      25.300000         26.000000         24.900000
#
#        composite_act_2017  participation_sat_2018  composite_sat_2018  \
# count           51.000000               51.000000           51.000000
# mean            21.519608               45.745098          563.686275
# std              2.020695               37.314256           47.502627
# min             17.800000                2.000000          480.000000
# 25%             19.800000                4.500000          534.500000
# 50%             21.400000               52.000000          552.000000
# 75%             23.600000               77.500000          610.500000
# max             25.500000              100.000000          643.000000
#
#        math_sat_2018  total_sat_2018  participation_act_2018  \
# count      51.000000       51.000000               51.000000
# mean      556.235294     1120.019608               61.647059
# std        47.772623       94.155083               34.080976
# min       480.000000      977.000000                7.000000
# 25%       522.500000     1057.500000               28.500000
# 50%       544.000000     1098.000000               66.000000
# 75%       593.500000     1204.000000              100.000000
# max       655.000000     1298.000000              100.000000
#
#        composite_act_2018  english_act_2018  math_act_2018  reading_act_2018  \
# count           51.000000         51.000000      51.000000         51.000000
# mean            21.486275         20.988235      21.125490         22.015686
# std              2.106278          2.446356       2.035765          2.167245
# min             17.700000         16.600000      17.800000         18.000000
# 25%             19.950000         19.100000      19.400000         20.450000
# 50%             21.300000         20.200000      20.700000         21.600000
# 75%             23.550000         23.700000      23.150000         24.100000
# max             25.600000         26.000000      25.200000         26.100000
#
#        science_act_2018
# count         51.000000
# mean          21.345098
# std            1.870114
# min           17.900000
# 25%           19.850000
# 50%           21.100000
# 75%           23.050000
# max           24.900000

# %%
sd
# Out:
# {'participation_sat_2017': 34.92907076664508,
#  'evidence-based_reading_and_writing_sat_2017': 45.21697020437866,
#  'math_sat_2017': 46.65713364485503,
#  'total_sat_2017': 91.58351056778743,
#  'participation_act_2017': 31.824175751231806,
#  'english_act_2017': 2.3304876369363363,
#  'math_act_2017': 1.9624620273436781,
#  'reading_act_2017': 2.0469029314842646,
#  'science_act_2017': 1.7222161451443676,
#  'composite_act_2017': 2.000786081581989,
#  'participation_sat_2018': 36.946619223539415,
#  'composite_sat_2018': 47.03460978357609,
#  'math_sat_2018': 47.30194550378352,
#  'total_sat_2018': 93.22742384464433,
#  'participation_act_2018': 33.745194881997506,
#  'composite_act_2018': 2.0855261815801147,
#  'english_act_2018': 2.4222536143202795,
#  'math_act_2018': 2.015707255555717,
#  'reading_act_2018': 2.145891884510421,
#  'science_act_2018': 1.8516885484833543}

# %%
np.std(merged_final) #standard deviation
# Out:
# participation_sat_2017                         34.929071
# evidence-based_reading_and_writing_sat_2017    45.216970
# math_sat_2017                                  46.657134
# total_sat_2017                                 91.583511
# participation_act_2017                         31.824176
# english_act_2017                                2.330488
# math_act_2017                                   1.962462
# reading_act_2017                                2.046903
# science_act_2017                                1.722216
# composite_act_2017                              2.000786
# participation_sat_2018                         36.946619
# composite_sat_2018                             47.034610
# math_sat_2018                                  47.301946
# total_sat_2018                                 93.227424
# participation_act_2018                         33.745195
# composite_act_2018                              2.085526
# english_act_2018                                2.422254
# math_act_2018                                   2.015707
# reading_act_2018                                2.145892
# science_act_2018                                1.851689
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer it does not matchup with the pandas describe function but does match up with numpy  standard deviations matches. This is because pandas calculation for std is for a sample and have a n-1 in the denominator instead of just n and the std formula is for entire population and not for a sample.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Utilizing sort_value functions to sort data frame by column.Highest participation rates for 2017 sat states are columbia ,michigan ,connecticut and 
#Delaware
merged_final.sort_values('participation_sat_2017', ascending = False)[['state_sat_2017', 'participation_sat_2017']].head(10)
# Out:
#           state_sat_2017  participation_sat_2017
# 8   District of Columbia                   100.0
# 22              Michigan                   100.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 29         New Hampshire                    96.0
# 19                 Maine                    95.0
# 12                 Idaho                    93.0
# 9                Florida                    83.0
# 21         Massachusetts                    76.0
# 39          Rhode Island                    71.0

# %%
merged_final.sort_values('participation_sat_2017', ascending = True)[['state_sat_2017', 'participation_sat_2017']].head(10)
#lowest participation rate for sat 2017 : north Dakota, Missipi and Iowa at 2%
# Out:
#    state_sat_2017  participation_sat_2017
# 34   North Dakota                     2.0
# 24    Mississippi                     2.0
# 15           Iowa                     2.0
# 25       Missouri                     3.0
# 44           Utah                     3.0
# 41   South Dakota                     3.0
# 27       Nebraska                     3.0
# 49      Wisconsin                     3.0
# 23      Minnesota                     3.0
# 50        Wyoming                     3.0

# %%
#the highest participation sat 2018 states are colorado , connecticut , delaware, Michigan, Idaho.

merged_final.sort_values('participation_sat_2018', ascending = False)[['state_sat_2018', 'participation_sat_2018']].head(20)
# Out:
#           state_sat_2018  participation_sat_2018
# 5               Colorado                   100.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 22              Michigan                   100.0
# 12                 Idaho                   100.0
# 19                 Maine                    99.0
# 13              Illinois                    99.0
# 39          Rhode Island                    97.0
# 29         New Hampshire                    96.0
# 8   District of Columbia                    92.0
# 30            New Jersey                    82.0
# 21         Massachusetts                    80.0
# 32              New York                    79.0
# 20              Maryland                    76.0
# 38          Pennsylvania                    70.0
# 10               Georgia                    70.0
# 47            Washington                    69.0
# 46              Virginia                    68.0
# 43                 Texas                    66.0
# 45               Vermont                    64.0

# %%
#Lowest Participartion rate for sat_2018 is North Dakota
merged_final.sort_values('participation_sat_2018', ascending = True)[['state_sat_2018', 'participation_sat_2018']].head(10)
# Out:
#    state_sat_2018  participation_sat_2018
# 34   North Dakota                     2.0
# 50        Wyoming                     3.0
# 41   South Dakota                     3.0
# 27       Nebraska                     3.0
# 49      Wisconsin                     3.0
# 24    Mississippi                     3.0
# 15           Iowa                     3.0
# 44           Utah                     4.0
# 23      Minnesota                     4.0
# 18      Louisiana                     4.0

# %%
# Highest participation rates for act 2017 is Alabama, Kentucky , Wisconsin, Utah , Tenessee, South Carolina, Oklahoma , North carolina ,Nevada,Montana , Misssisipi , Minnesota , Lousiana,
#missouri ,wyoming,colorado , Arkansas
merged_final.sort_values('participation_act_2017', ascending = False)[['state_sat_2017', 'participation_act_2017']].head(20)
# Out:
#     state_sat_2017  participation_act_2017
# 0          Alabama                   100.0
# 17        Kentucky                   100.0
# 49       Wisconsin                   100.0
# 44            Utah                   100.0
# 42       Tennessee                   100.0
# 40  South Carolina                   100.0
# 36        Oklahoma                   100.0
# 33  North Carolina                   100.0
# 28          Nevada                   100.0
# 26         Montana                   100.0
# 24     Mississippi                   100.0
# 23       Minnesota                   100.0
# 18       Louisiana                   100.0
# 25        Missouri                   100.0
# 50         Wyoming                   100.0
# 5         Colorado                   100.0
# 3         Arkansas                   100.0
# 34    North Dakota                    98.0
# 13        Illinois                    93.0
# 11          Hawaii                    90.0

# %%
#lowest participation act 2017 rate is 8% at Maine
merged_final.sort_values('participation_act_2017', ascending = True)[['state_sat_2017', 'participation_act_2017']].head(20)
# Out:
#           state_sat_2017  participation_act_2017
# 19                 Maine                     8.0
# 29         New Hampshire                    18.0
# 7               Delaware                    18.0
# 39          Rhode Island                    21.0
# 38          Pennsylvania                    23.0
# 20              Maryland                    28.0
# 45               Vermont                    29.0
# 21         Massachusetts                    29.0
# 22              Michigan                    29.0
# 46              Virginia                    29.0
# 47            Washington                    29.0
# 4             California                    31.0
# 32              New York                    31.0
# 6            Connecticut                    31.0
# 8   District of Columbia                    32.0
# 30            New Jersey                    34.0
# 14               Indiana                    35.0
# 12                 Idaho                    38.0
# 37                Oregon                    40.0
# 43                 Texas                    45.0

# %%
#sorting highest participation rate for act2018
#Highest are Alabama ,Kentucky, Winsconsin,Utah ,Tennessee, SouthCarolina , OKlhahoma , Ohio,North Carolina,Nevada
#Nebraska ,montana, Missisipi, Lousiana,Missouri, Wyoming , Arkansas at 100%.

merged_final.sort_values('participation_act_2018', ascending = False)[['state_act_2018', 'participation_act_2018']].head(20)
# Out:
#     state_act_2018  participation_act_2018
# 0          Alabama                   100.0
# 17        Kentucky                   100.0
# 49       Wisconsin                   100.0
# 44            Utah                   100.0
# 42       Tennessee                   100.0
# 40  South Carolina                   100.0
# 36        Oklahoma                   100.0
# 35            Ohio                   100.0
# 33  North Carolina                   100.0
# 28          Nevada                   100.0
# 27        Nebraska                   100.0
# 26         Montana                   100.0
# 24     Mississippi                   100.0
# 18       Louisiana                   100.0
# 25        Missouri                   100.0
# 50         Wyoming                   100.0
# 3         Arkansas                   100.0
# 23       Minnesota                    99.0
# 34    North Dakota                    98.0
# 11          Hawaii                    89.0

# %%
#Lowest participation rate 2018 act is maine at 7%
merged_final.sort_values('participation_act_2018', ascending = True)[['state_act_2018', 'participation_act_2018']].head(20)
# Out:
#           state_act_2018  participation_act_2018
# 19                 Maine                     7.0
# 39          Rhode Island                    15.0
# 29         New Hampshire                    16.0
# 7               Delaware                    17.0
# 38          Pennsylvania                    20.0
# 22              Michigan                    22.0
# 47            Washington                    24.0
# 45               Vermont                    24.0
# 46              Virginia                    24.0
# 21         Massachusetts                    25.0
# 6            Connecticut                    26.0
# 4             California                    27.0
# 32              New York                    27.0
# 5               Colorado                    30.0
# 30            New Jersey                    31.0
# 20              Maryland                    31.0
# 14               Indiana                    32.0
# 8   District of Columbia                    32.0
# 1                 Alaska                    33.0
# 12                 Idaho                    36.0

# %%
merged_final.head(3)
# Out:
#   state_sat_2017  participation_sat_2017  \
# 0        Alabama                     5.0
# 1         Alaska                    38.0
# 2        Arizona                    30.0
#
#    evidence-based_reading_and_writing_sat_2017  math_sat_2017  total_sat_2017  \
# 0                                        593.0          572.0          1165.0
# 1                                        547.0          533.0          1080.0
# 2                                        563.0          553.0          1116.0
#
#   state_act_2017  participation_act_2017  english_act_2017  math_act_2017  \
# 0        Alabama                   100.0              18.9           18.4
# 1         Alaska                    65.0              18.7           19.8
# 2        Arizona                    62.0              18.6           19.8
#
#    reading_act_2017  ...  composite_sat_2018  math_sat_2018 total_sat_2018  \
# 0              19.7  ...               595.0          571.0         1166.0
# 1              20.4  ...               562.0          544.0         1106.0
# 2              20.1  ...               577.0          572.0         1149.0
#
#    state_act_2018  participation_act_2018  composite_act_2018  \
# 0         Alabama                   100.0                19.1
# 1          Alaska                    33.0                20.8
# 2         Arizona                    66.0                19.2
#
#    english_act_2018 math_act_2018  reading_act_2018  science_act_2018
# 0              18.9          18.3              19.6              19.0
# 1              19.8          20.6              21.6              20.7
# 2              18.2          19.4              19.5              19.2
#
# [3 rows x 24 columns]

# %%
#Highest Sat score 2017 is Minnesota 1295 
merged_final.sort_values('total_sat_2017', ascending = False)[['state_sat_2017', 'total_sat_2017']].head(10)
# Out:
#    state_sat_2017  total_sat_2017
# 23      Minnesota          1295.0
# 49      Wisconsin          1291.0
# 15           Iowa          1275.0
# 25       Missouri          1271.0
# 16         Kansas          1260.0
# 34   North Dakota          1256.0
# 27       Nebraska          1253.0
# 17       Kentucky          1247.0
# 24    Mississippi          1242.0
# 44           Utah          1238.0

# %%
#Lowest Sat 2017 score is district of columbia at 950.
merged_final.sort_values('total_sat_2017', ascending = True)[['state_sat_2017', 'total_sat_2017']].head(10)
# Out:
#           state_sat_2017  total_sat_2017
# 8   District of Columbia           950.0
# 7               Delaware           996.0
# 12                 Idaho          1005.0
# 22              Michigan          1005.0
# 19                 Maine          1012.0
# 9                Florida          1017.0
# 43                 Texas          1020.0
# 6            Connecticut          1041.0
# 36              Oklahoma          1047.0
# 10               Georgia          1050.0

# %%
#Highest composite sat 2018 score is 1298 Minnesota
merged_final.sort_values('total_sat_2018', ascending = False)[['state_sat_2018', 'total_sat_2018']].head(10)
# Out:
#    state_sat_2018  total_sat_2018
# 23      Minnesota          1298.0
# 49      Wisconsin          1294.0
# 34   North Dakota          1283.0
# 15           Iowa          1265.0
# 16         Kansas          1265.0
# 25       Missouri          1262.0
# 50        Wyoming          1257.0
# 27       Nebraska          1252.0
# 17       Kentucky          1248.0
# 41   South Dakota          1240.0

# %%
#lowest composite score 2018 is 977 at Distrct of columbia at 977
merged_final.sort_values('total_sat_2018', ascending = True)[['state_sat_2018', 'total_sat_2018']].head(10)
# Out:
#           state_sat_2018  total_sat_2018
# 8   District of Columbia           977.0
# 7               Delaware           998.0
# 48         West Virginia           999.0
# 12                 Idaho          1001.0
# 44                  Utah          1010.0
# 11                Hawaii          1010.0
# 22              Michigan          1011.0
# 19                 Maine          1013.0
# 39          Rhode Island          1018.0
# 13              Illinois          1019.0

# %%
#Highest composite score for act 2017 is New Hampshire 25.5
merged_final.sort_values('composite_act_2017', ascending = False )[['state_act_2017', 'composite_act_2017']].head(10)
# Out:
#           state_act_2017  composite_act_2017
# 29         New Hampshire                25.5
# 21         Massachusetts                25.4
# 6            Connecticut                25.2
# 19                 Maine                24.3
# 8   District of Columbia                24.2
# 32              New York                24.2
# 22              Michigan                24.1
# 7               Delaware                24.1
# 39          Rhode Island                24.0
# 30            New Jersey                23.9

# %%
#Lowest composite score is nevada at 17.8 for act 2017.
merged_final.sort_values('composite_act_2017', ascending = True )[['state_act_2017', 'composite_act_2017']].head(10)
# Out:
#     state_act_2017  composite_act_2017
# 28          Nevada                17.8
# 24     Mississippi                18.6
# 40  South Carolina                18.7
# 11          Hawaii                19.0
# 33  North Carolina                19.1
# 0          Alabama                19.2
# 3         Arkansas                19.4
# 36        Oklahoma                19.4
# 18       Louisiana                19.5
# 2          Arizona                19.7

# %%
#using the sort_values function to sort data frame by column , 'ascending ' was set tom True to obtain min values
#onmly columnbs' Total_act_2018 ' and 'Composite_act_2018' were selected to be displayed
#.head(10) to display top 10 values
#lowest composite score for act 2018 is nevada at 17.7
merged_final.sort_values('composite_act_2018', ascending = True )[['state_act_2018', 'composite_act_2018']].head(10)
# Out:
#     state_act_2018  composite_act_2018
# 28          Nevada                17.7
# 40  South Carolina                18.3
# 24     Mississippi                18.6
# 11          Hawaii                18.9
# 0          Alabama                19.1
# 33  North Carolina                19.1
# 2          Arizona                19.2
# 18       Louisiana                19.2
# 36        Oklahoma                19.3
# 3         Arkansas                19.4

# %%
#Highest composite score is connecticut at 25.6
merged_final.sort_values('composite_act_2018', ascending = False )[['state_act_2018', 'composite_act_2018']].head(10)
# Out:
#    state_act_2018  composite_act_2018
# 6     Connecticut                25.6
# 21  Massachusetts                25.5
# 29  New Hampshire                25.1
# 32       New York                24.5
# 22       Michigan                24.4
# 39   Rhode Island                24.2
# 45        Vermont                24.1
# 19          Maine                24.0
# 46       Virginia                23.9
# 5        Colorado                23.9

# %%
# Utilize masking to display rows at which 'participation_sat_2017' and 'participation_sat_2018' is equal to 100
# Only the state and participation rate collumns were selected to be displayed
merged_final[(merged_final['participation_sat_2017']==100)&(merged_final['participation_sat_2018']==100)][['state_sat_2017','participation_sat_2017','participation_sat_2018']]
# Out:
#    state_sat_2017  participation_sat_2017  participation_sat_2018
# 6     Connecticut                   100.0                   100.0
# 7        Delaware                   100.0                   100.0
# 22       Michigan                   100.0                   100.0

# %%
#Count values at which 'participation_sat_2017' is equal to 100

merged_final[merged_final['participation_sat_2017']==100]['state_sat_2017'].count()
# Out:
# 4

# %%
# Count values at which 'participation_sat_2017' and 'participation_sat_2018' is equal to 100 no rate change
merged_final[(merged_final['participation_sat_2017']==100)&(merged_final['participation_sat_2018']==100)]['state_sat_2017'].count()
# Out:
# 3

# %%
#count 100% participation rate in act2017
merged_final[(merged_final['participation_act_2017']==100)]['state_act_2017'].count()
# Out:
# 17

# %%
# Count values at which 'participation_act_2017' and 'percentageofstudentstested_act_2018' is equal to 100
#100% participation rate actually dropped.
merged_final[(merged_final['participation_act_2017']==100)&(merged_final['participation_act_2018']==100)]['state_sat_2017'].count()
# Out:
# 15

# %%
# Utilizing masking to display states that have a participation rate in 2017 that is higher than 50% in both SAT and ACT
merged_final[(merged_final['participation_act_2017']>50) & (merged_final['participation_sat_2017']>50)][['state_sat_2017', 'participation_sat_2017', 'participation_act_2017']]
# Out:
#    state_sat_2017  participation_sat_2017  participation_act_2017
# 9         Florida                    83.0                    73.0
# 10        Georgia                    61.0                    55.0
# 11         Hawaii                    55.0                    90.0

# %%
# Utilizing masking to display states that have a participation rate in 2018 that is higher than 50% in both SAT and ACT
merged_final[(merged_final['participation_act_2018']>50) & (merged_final['participation_sat_2018']>50)][['state_sat_2018', 'participation_sat_2018', 'participation_act_2018']]
# Out:
#     state_sat_2018  participation_sat_2018  participation_act_2018
# 9          Florida                    56.0                    66.0
# 10         Georgia                    70.0                    53.0
# 11          Hawaii                    56.0                    89.0
# 33  North Carolina                    52.0                   100.0
# 40  South Carolina                    55.0                   100.0

# %% [markdown]
# Seems that florida georgia and hawaii had more participation rates , and north carolina and sorth carolina suddenly increased to 100% participation rates for act 2018.
#
# that is a huge jump! We must investigate the reasons

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#utilizing seaborn to plot heatmap of all variables for SAT2017, SAT2018, ACT2017, ACT2018
fig, ax = plt.subplots(figsize=(15,8)) # setting the figsize to 15,8
heatmat= np.triu(merged_final.corr())#creating the mask using upper triangle numpy array

#plotting the heatmap via heatmap function
sns.heatmap(merged_final.corr(), annot = True , fmt ='2g', mask = heatmat)\
.set_title('Heatmap- All Variables -SAT2017, SAT2018, ACT2017, ACT2018', fontsize =20);

# %%
plt.figure(figsize = (20,12))
ax = sns.heatmap(merged_final.corr(), annot=True, annot_kws={"size": 14})
ax.set_title('Correlation ACT/SAT for 2017/2018', fontsize=21, y=1.01);
ax

# %%
# Utilizing seaborn to plot heatmap of participation, total, and composite in SAT 2018, ACT 2017, and ACT 2018
fig, ax = plt.subplots(figsize = (15,8)) # Setting the figsize to 15, 8
# Creating the mask using upper triangle numpy array
# Line continuation character has been implemented to improve readability
heatmat = np.triu(merged_final[['participation_sat_2017', \
                                    'participation_sat_2018', \
                                    'participation_act_2017', \
                                    'participation_act_2018', \
                                    'total_sat_2017', \
                                    'total_sat_2018', \
                                    'composite_act_2017', \
                                    'composite_act_2018']].corr())
# Plotting the heatmap via heatmap function
# Line continuation character has been implemented to improve readability
sns.heatmap(merged_final[['participation_sat_2017', \
                              'participation_sat_2018', \
                              'participation_act_2017', \
                              'participation_act_2018', \
                              'total_sat_2017', \
                              'total_sat_2018', \
                              'composite_act_2017', \
                              'composite_act_2018']].corr(), \
            annot = True, fmt='.2g', mask=heatmat)\
.set_title('Heatmap - Participation, Total, and Composite - SAT 2017, SAT 2018, ACT 2017, ACT 2018', fontsize = 15);

# %%
# Function that accepts the names of 2+ columns and plots histograms into subplots.
def subplot_histograms(list_of_columns, dataframe = merged_final): # Setting the default dataframe to be 'pan_merged_final'
    temp_list = [] # Creating a temporary list to help us remove unwanted 'state' columns in the pan_merged_final dataframe
    for name in list_of_columns: # for loop iterates for every column in 'list_of_columns'
        if 'state' in name: # Conditional if statement will pass if the string 'state' is in the column name
            pass
        else: # If 'state' is not in the column name, column name will be appended into 'temp_list'
            temp_list.append(name)
    list_of_columns = temp_list # Setting 'list_of_columns' to 'temp_list'
    nrows = int(np.ceil(len(list_of_columns)/2)) # Counting the number of rows required
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (15,10*nrows/2)) # figsize is scaled based on number of rows
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].grid() # Turns grid on for every iteration (every subplot)
        ax[i].grid(which='major', alpha=0.4) # Sets grid opacity
        ax[i].set_yticks(np.arange(0,52,1)) #
        ax[i].hist(dataframe[column], bins = 15) # Histogram plot in subplot of index i
        # Setting title that will generate based on column name
        ax[i].set_title('Histogram - ' + column.replace('_', ' ').split()[0].title() + ' ' \
                        + column.replace('_', ' ').split()[1].upper() + ' ' \
                        + column.replace('_', ' ').split()[2])
        # Setting y label to be 'number of US states'
        ax[i].set_ylabel('Number of US States (n = ' + str(len(dataframe.index)) +')')
        # If statement controls x label, as participation rate requires a different format
        if 'participation' in column:
            ax[i].set_xlabel('Participation Rate (%)')
        else:
            ax[i].set_xlabel('Mean ' + column.replace('_', ' ').split()[0].title() + ' '\
                             + 'Score')

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
subplot_histograms([n for n in merged_final if 'participation' in n])

# %% [markdown]
# Analysis of histogram:
#
# For overall population , appears there is a randomn distribution with noo pattern.
# highest peak in SAT participation rates resides in participation rates of 100% in 6-8 states or less than 10% for all states.
# Highest Participationr rates for ACT participation between 90%-100% for both years.
# Appears that participation rates btw ACT scores or SAT scores have a high correlation year on year.
#
# good to investigate.

# %%
subplot_histograms([n for n in merged_final if 'math' in n])

# %% [markdown]
# Analysis of math scores, we see a normal distribution for math scores in ACT and SAT scores .
# for SAT scores , the peak number of states scoring in SAT scores scoring between 525-550.
# For Act scores , the peak number of states scoring between 19-20.
# math scores appear to have high correlation based on shape for ACT and SAT scores.

# %%
merged_final.head(3)
# Out:
#   state_sat_2017  participation_sat_2017  \
# 0        Alabama                     5.0
# 1         Alaska                    38.0
# 2        Arizona                    30.0
#
#    evidence-based_reading_and_writing_sat_2017  math_sat_2017  total_sat_2017  \
# 0                                        593.0          572.0          1165.0
# 1                                        547.0          533.0          1080.0
# 2                                        563.0          553.0          1116.0
#
#   state_act_2017  participation_act_2017  english_act_2017  math_act_2017  \
# 0        Alabama                   100.0              18.9           18.4
# 1         Alaska                    65.0              18.7           19.8
# 2        Arizona                    62.0              18.6           19.8
#
#    reading_act_2017  ...  composite_sat_2018  math_sat_2018 total_sat_2018  \
# 0              19.7  ...               595.0          571.0         1166.0
# 1              20.4  ...               562.0          544.0         1106.0
# 2              20.1  ...               577.0          572.0         1149.0
#
#    state_act_2018  participation_act_2018  composite_act_2018  \
# 0         Alabama                   100.0                19.1
# 1          Alaska                    33.0                20.8
# 2         Arizona                    66.0                19.2
#
#    english_act_2018 math_act_2018  reading_act_2018  science_act_2018
# 0              18.9          18.3              19.6              19.0
# 1              19.8          20.6              21.6              20.7
# 2              18.2          19.4              19.5              19.2
#
# [3 rows x 24 columns]

# %%
subplot_histograms([n for n in merged_final if ('reading' in n)| ('english'in n)])

# %% [markdown]
# Reading scores seems to have the highest mean at 21 for ACT scores

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def scatter_plot(list_of_columns, title ,xlabel , ylabel , dataframe= merged_final):
    fig, ax =plt.subplots(figsize =(15,10)) # specify figsize
    plt.xticks(fontsize =14) #setting fontsize of x axis legend
    plt.yticks(fontsize=14) #seng y axis label to plot
    plt.grid()# apply grid to plot
    plt.grid(which ='major', alpha=0.4) #set grid opacity
    ax.set_xlabel(xlabel, fontsize =17) #Applying x axis label to plot
    ax.set_ylabel(ylabel, fontsize =17) #applyi # plotting the scatter plot
    ax.set_title(title, fontsize = 22) # applying titlte to plot
    
    plt.scatter(dataframe[list_of_columns[0]],dataframe[list_of_columns[1]], c= 'crimson', s =120)

# %%
# Code function to plot a scattter plot of math_sat_2017 vs math_act_2017
scatter_plot(['math_sat_2017' , 'math_act_2017'], 'Scatter Plot of State ACT and SAT Mean Math Scores in 2017',\
              'Mean Sat Math Score', 'Mean ACT math Score ')

# %% [markdown]
# there is no cluttering and seems to have no correlation no line drawn on exponential curve. it is scattered.

# %%
merged_final.head(2) # just to see our column headers
# Out:
#   state_sat_2017  participation_sat_2017  \
# 0        Alabama                     5.0
# 1         Alaska                    38.0
#
#    evidence-based_reading_and_writing_sat_2017  math_sat_2017  total_sat_2017  \
# 0                                        593.0          572.0          1165.0
# 1                                        547.0          533.0          1080.0
#
#   state_act_2017  participation_act_2017  english_act_2017  math_act_2017  \
# 0        Alabama                   100.0              18.9           18.4
# 1         Alaska                    65.0              18.7           19.8
#
#    reading_act_2017  ...  composite_sat_2018  math_sat_2018 total_sat_2018  \
# 0              19.7  ...               595.0          571.0         1166.0
# 1              20.4  ...               562.0          544.0         1106.0
#
#    state_act_2018  participation_act_2018  composite_act_2018  \
# 0         Alabama                   100.0                19.1
# 1          Alaska                    33.0                20.8
#
#    english_act_2018 math_act_2018  reading_act_2018  science_act_2018
# 0              18.9          18.3              19.6              19.0
# 1              19.8          20.6              21.6              20.7
#
# [2 rows x 24 columns]

# %%
#saving a copy of merged_final in dataframe verbal_df (verbal dataframe)

verbal_df=merged_final

#Summing the two verbal components in the ACT test
verbal_df['verbal_act_2017']= verbal_df['english_act_2017']+verbal_df['reading_act_2017']

#Calling 'Scatter_plot' function to plot a scatter plot of verbal test scores between SAT and ACT in 2017'
scatter_plot(['evidence-based_reading_and_writing_sat_2017','verbal_act_2017'],
\
             'Scatter Plot of State ACT and SAT mean verbal scores in 2017',\
             'mean SAT english based reading and writing score',\
             'Mean ACT verbal score (English and Reading Sum)',\
             dataframe=verbal_df)

# %% [markdown]
# There is no signficant clustering and no observable trend.

# %%
#calling scatterplot function to plot a scatter plot of total_sat_2017  vs composite_act_2017
scatter_plot(['total_sat_2017', 'composite_act_2017'], 'Scatter Plot of State ACT and SAT Composite/Total Scores in 2017',\
             'Mean SAT total score', 'Mean ACT Composite Score')

# %% [markdown]
# Appears to have no clustering and no obeservable trend.

# %%
#calling scatterplot function to plopt the scatter plot of totalsat2017 and totalsat2018 scores
scatter_plot(['total_sat_2017', 'total_sat_2018'], 'Scatter Plot of SAT total scores in 2017 and 2018',\
             'Mean Total Score 2017 ', 'Mean Total score 2018')

# %% [markdown]
# IT looks to be linear and to be positively correlated with a few outliers ,thus they might have similar scores  in 2017 and 2018.

# %%
scatter_plot(['composite_act_2017', 'composite_act_2018'], 'Scatter Plot of ACT composite scores in 2017 and 2018',\
             'Mean Composite Score 2017','Mean Composite Score 2018')

# %% [markdown]
# For the scatter plot of act composite scores in 2017 and 20178 , there is a srong correlation as shown by the plots following a straight line , a linear correlation with only a few outliers.
#
# This means that it is likely to have similar composite scores for act 2017 and 2018

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code

def box_plott(column_names, xtick_labels ,ylabel, title , fndf =merged_final):
    fig , ax = plt.subplots(figsize =(15,12))
    df= pd.DataFrame(data=fndf, columns = column_names)
    plt.xticks(fontsize =15)
    plt.yticks(fontsize =18)
    
    #plt.grid()
    plotty=sns.boxplot(x='variable', y ='value', data= pd.melt(df), showfliers= True )
    sns.swarmplot(x='variable', y='value', data=pd.melt(df), color='gold', edgecolor = 'brown' ,size =8)
    plotty.axes.set_title(title,fontsize = 25)
    plotty.set_xlabel('', fontsize =20)
    plotty.set_ylabel(ylabel, fontsize =20)
    plotty.set(xticklabels=xtick_labels);

# %%
box_plott(['participation_sat_2017', 'participation_sat_2018','participation_act_2017', 'participation_act_2018'],\
          ['2017 SAT participation', '2018 SAT participation' , '2017 ACT participation' , '2018 ACT Participation'],
          'State Participation Rate (%)',
          'Box Plot - Participation Rate - SAT and ACT in 2017 and 2018 ')

# %%
merged_final.columns
# Out:
# Index(['state_sat_2017', 'participation_sat_2017',
#        'evidence-based_reading_and_writing_sat_2017', 'math_sat_2017',
#        'total_sat_2017', 'state_act_2017', 'participation_act_2017',
#        'english_act_2017', 'math_act_2017', 'reading_act_2017',
#        'science_act_2017', 'composite_act_2017', 'state_sat_2018',
#        'participation_sat_2018', 'composite_sat_2018', 'math_sat_2018',
#        'total_sat_2018', 'state_act_2018', 'participation_act_2018',
#        'composite_act_2018', 'english_act_2018', 'math_act_2018',
#        'reading_act_2018', 'science_act_2018', 'verbal_act_2017'],
#       dtype='object')

# %%
box_plott(['math_sat_2017', 'math_sat_2018','evidence-based_reading_and_writing_sat_2017', 'composite'],\
          ['2017 SAT Math', '2018 SAT Math' , '2017 SAT EBRW' , '2018 SAT Ebrw'],
          'State Mean Score',
          'Box Plot - SAT MATH and EBRW mean score in 2017 and 2018 ')

# %%
box_plott(['total_sat_2017', 'total_sat_2018'],\
           ['2017 SAT total',  '2018 SAT total'],
           'State mean Score ',
           'Box Plot- SAT Total mean Score in 2017 and 2018')

# %%
box_plott(['reading_act_2017','reading_act_2018',\
           'english_act_2017', 'english_act_2018'],\
           ['2017 ACT Reading ', '2018 ACT Reading',\
            '2017 ACT English' , '2018 ACT English'],
          'State Mean Score',
          'Box Plot - ACT verbal Mean Score in 2017 and 2018')

# %%
box_plott(['math_act_2017','math_act_2018',\
          'science_act_2017','science_act_2018',\
          'composite_act_2017', 'composite_act_2018'],\
          ['2017 Math ','2018 Math',\
           '2017 Science' , '2018 Science',\
           '2017 Composite', '2018 Composite'],
          'State Mean Score',
          'Box plot - ACT math , Science , Composite Scores in 2017 and 2018 ')

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# none at the moment.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
merged_final.columns
# Out:
# Index(['state_sat_2017', 'participation_sat_2017',
#        'evidence-based_reading_and_writing_sat_2017', 'math_sat_2017',
#        'total_sat_2017', 'state_act_2017', 'participation_act_2017',
#        'english_act_2017', 'math_act_2017', 'reading_act_2017',
#        'science_act_2017', 'composite_act_2017', 'state_sat_2018',
#        'participation_sat_2018', 'composite_sat_2018', 'math_sat_2018',
#        'total_sat_2018', 'state_act_2018', 'participation_act_2018',
#        'composite_act_2018', 'english_act_2018', 'math_act_2018',
#        'reading_act_2018', 'science_act_2018', 'verbal_act_2017'],
#       dtype='object')

# %%
merged_final.head(52)
# Out:
#           state_sat_2017  participation_sat_2017  \
# 0                Alabama                     5.0
# 1                 Alaska                    38.0
# 2                Arizona                    30.0
# 3               Arkansas                     3.0
# 4             California                    53.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 9                Florida                    83.0
# 10               Georgia                    61.0
# 11                Hawaii                    55.0
# 12                 Idaho                    93.0
# 13              Illinois                     9.0
# 14               Indiana                    63.0
# 15                  Iowa                     2.0
# 16                Kansas                     4.0
# 17              Kentucky                     4.0
# 18             Louisiana                     4.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
# 21         Massachusetts                    76.0
# 22              Michigan                   100.0
# 23             Minnesota                     3.0
# 24           Mississippi                     2.0
# 25              Missouri                     3.0
# 26               Montana                    10.0
# 27              Nebraska                     3.0
# 28                Nevada                    26.0
# 29         New Hampshire                    96.0
# 30            New Jersey                    70.0
# 31            New Mexico                    11.0
# 32              New York                    67.0
# 33        North Carolina                    49.0
# 34          North Dakota                     2.0
# 35                  Ohio                    12.0
# 36              Oklahoma                     7.0
# 37                Oregon                    43.0
# 38          Pennsylvania                    65.0
# 39          Rhode Island                    71.0
# 40        South Carolina                    50.0
# 41          South Dakota                     3.0
# 42             Tennessee                     5.0
# 43                 Texas                    62.0
# 44                  Utah                     3.0
# 45               Vermont                    60.0
# 46              Virginia                    65.0
# 47            Washington                    64.0
# 48         West Virginia                    14.0
# 49             Wisconsin                     3.0
# 50               Wyoming                     3.0
#
#     evidence-based_reading_and_writing_sat_2017  math_sat_2017  \
# 0                                         593.0          572.0
# 1                                         547.0          533.0
# 2                                         563.0          553.0
# 3                                         614.0          594.0
# 4                                         531.0          524.0
# 5                                         606.0          595.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# 8                                         482.0          468.0
# 9                                         520.0          497.0
# 10                                        535.0          515.0
# 11                                        544.0          541.0
# 12                                        513.0          493.0
# 13                                        559.0          556.0
# 14                                        542.0          532.0
# 15                                        641.0          635.0
# 16                                        632.0          628.0
# 17                                        631.0          616.0
# 18                                        611.0          586.0
# 19                                        513.0          499.0
# 20                                        536.0          524.0
# 21                                        555.0          551.0
# 22                                        509.0          495.0
# 23                                        644.0          651.0
# 24                                        634.0          607.0
# 25                                        640.0          631.0
# 26                                        605.0          591.0
# 27                                        629.0          625.0
# 28                                        563.0          553.0
# 29                                        532.0          520.0
# 30                                        530.0          526.0
# 31                                        577.0          561.0
# 32                                        528.0          523.0
# 33                                        546.0          535.0
# 34                                        635.0          621.0
# 35                                        578.0          570.0
# 36                                        530.0          517.0
# 37                                        560.0          548.0
# 38                                        540.0          531.0
# 39                                        539.0          524.0
# 40                                        543.0          521.0
# 41                                        612.0          603.0
# 42                                        623.0          604.0
# 43                                        513.0          507.0
# 44                                        624.0          614.0
# 45                                        562.0          551.0
# 46                                        561.0          541.0
# 47                                        541.0          534.0
# 48                                        558.0          528.0
# 49                                        642.0          649.0
# 50                                        626.0          604.0
#
#     total_sat_2017        state_act_2017  participation_act_2017  \
# 0           1165.0               Alabama                   100.0
# 1           1080.0                Alaska                    65.0
# 2           1116.0               Arizona                    62.0
# 3           1208.0              Arkansas                   100.0
# 4           1055.0            California                    31.0
# 5           1201.0              Colorado                   100.0
# 6           1041.0           Connecticut                    31.0
# 7            996.0              Delaware                    18.0
# 8            950.0  District of Columbia                    32.0
# 9           1017.0               Florida                    73.0
# 10          1050.0               Georgia                    55.0
# 11          1085.0                Hawaii                    90.0
# 12          1005.0                 Idaho                    38.0
# 13          1115.0              Illinois                    93.0
# 14          1074.0               Indiana                    35.0
# 15          1275.0                  Iowa                    67.0
# 16          1260.0                Kansas                    73.0
# 17          1247.0              Kentucky                   100.0
# 18          1198.0             Louisiana                   100.0
# 19          1012.0                 Maine                     8.0
# 20          1060.0              Maryland                    28.0
# 21          1107.0         Massachusetts                    29.0
# 22          1005.0              Michigan                    29.0
# 23          1295.0             Minnesota                   100.0
# 24          1242.0           Mississippi                   100.0
# 25          1271.0              Missouri                   100.0
# 26          1196.0               Montana                   100.0
# 27          1253.0              Nebraska                    84.0
# 28          1116.0                Nevada                   100.0
# 29          1052.0         New Hampshire                    18.0
# 30          1056.0            New Jersey                    34.0
# 31          1138.0            New Mexico                    66.0
# 32          1052.0              New York                    31.0
# 33          1081.0        North Carolina                   100.0
# 34          1256.0          North Dakota                    98.0
# 35          1149.0                  Ohio                    75.0
# 36          1047.0              Oklahoma                   100.0
# 37          1108.0                Oregon                    40.0
# 38          1071.0          Pennsylvania                    23.0
# 39          1062.0          Rhode Island                    21.0
# 40          1064.0        South Carolina                   100.0
# 41          1216.0          South Dakota                    80.0
# 42          1228.0             Tennessee                   100.0
# 43          1020.0                 Texas                    45.0
# 44          1238.0                  Utah                   100.0
# 45          1114.0               Vermont                    29.0
# 46          1102.0              Virginia                    29.0
# 47          1075.0            Washington                    29.0
# 48          1086.0         West Virginia                    69.0
# 49          1291.0             Wisconsin                   100.0
# 50          1230.0               Wyoming                   100.0
#
#     english_act_2017  math_act_2017  reading_act_2017  ...  math_sat_2018  \
# 0               18.9           18.4              19.7  ...          571.0
# 1               18.7           19.8              20.4  ...          544.0
# 2               18.6           19.8              20.1  ...          572.0
# 3               18.9           19.0              19.7  ...          576.0
# 4               22.5           22.7              23.1  ...          536.0
# 5               20.1           20.3              21.2  ...          506.0
# 6               25.5           24.6              25.6  ...          519.0
# 7               24.1           23.4              24.8  ...          492.0
# 8               24.4           23.5              24.9  ...          480.0
# 9               19.0           19.4              21.0  ...          549.0
# 10              21.0           20.9              22.0  ...          522.0
# 11              17.8           19.2              19.2  ...          530.0
# 12              21.9           21.8              23.0  ...          493.0
# 13              21.0           21.2              21.6  ...          506.0
# 14              22.0           22.4              23.2  ...          532.0
# 15              21.2           21.3              22.6  ...          631.0
# 16              21.1           21.3              22.3  ...          631.0
# 17              19.6           19.4              20.5  ...          618.0
# 18              19.4           18.8              19.8  ...          595.0
# 19              24.2           24.0              24.8  ...          501.0
# 20              23.3           23.1              24.2  ...          535.0
# 21              25.4           25.3              25.9  ...          563.0
# 22              24.1           23.7              24.5  ...          499.0
# 23              20.4           21.5              21.8  ...          655.0
# 24              18.2           18.1              18.8  ...          606.0
# 25              19.8           19.9              20.8  ...          629.0
# 26              19.0           20.2              21.0  ...          592.0
# 27              20.9           20.9              21.9  ...          623.0
# 28              16.3           18.0              18.1  ...          566.0
# 29              25.4           25.1              26.0  ...          528.0
# 30              23.8           23.8              24.1  ...          547.0
# 31              18.6           19.4              20.4  ...          540.0
# 32              23.8           24.0              24.6  ...          534.0
# 33              17.8           19.3              19.6  ...          543.0
# 34              19.0           20.4              20.5  ...          643.0
# 35              21.2           21.6              22.5  ...          547.0
# 36              18.5           18.8              20.1  ...          521.0
# 37              21.2           21.5              22.4  ...          553.0
# 38              23.4           23.4              24.2  ...          539.0
# 39              24.0           23.3              24.7  ...          505.0
# 40              17.5           18.6              19.1  ...          523.0
# 41              20.7           21.5              22.3  ...          618.0
# 42              19.5           19.2              20.1  ...          607.0
# 43              19.5           20.7              21.1  ...          512.0
# 44              19.5           19.9              20.8  ...          530.0
# 45              23.3           23.1              24.4  ...          554.0
# 46              23.5           23.3              24.6  ...          550.0
# 47              20.9           21.9              22.1  ...          538.0
# 48              20.0           19.4              21.2  ...          486.0
# 49              19.7           20.4              20.6  ...          653.0
# 50              19.4           19.8              20.8  ...          625.0
#
#     total_sat_2018        state_act_2018  participation_act_2018  \
# 0           1166.0               Alabama                   100.0
# 1           1106.0                Alaska                    33.0
# 2           1149.0               Arizona                    66.0
# 3           1169.0              Arkansas                   100.0
# 4           1076.0            California                    27.0
# 5           1025.0              Colorado                    30.0
# 6           1053.0           Connecticut                    26.0
# 7            998.0              Delaware                    17.0
# 8            977.0  District of Columbia                    32.0
# 9           1099.0               Florida                    66.0
# 10          1064.0               Georgia                    53.0
# 11          1010.0                Hawaii                    89.0
# 12          1001.0                 Idaho                    36.0
# 13          1019.0              Illinois                    43.0
# 14          1074.0               Indiana                    32.0
# 15          1265.0                  Iowa                    68.0
# 16          1265.0                Kansas                    71.0
# 17          1248.0              Kentucky                   100.0
# 18          1210.0             Louisiana                   100.0
# 19          1013.0                 Maine                     7.0
# 20          1080.0              Maryland                    31.0
# 21          1125.0         Massachusetts                    25.0
# 22          1011.0              Michigan                    22.0
# 23          1298.0             Minnesota                    99.0
# 24          1236.0           Mississippi                   100.0
# 25          1262.0              Missouri                   100.0
# 26          1198.0               Montana                   100.0
# 27          1252.0              Nebraska                   100.0
# 28          1140.0                Nevada                   100.0
# 29          1063.0         New Hampshire                    16.0
# 30          1094.0            New Jersey                    31.0
# 31          1093.0            New Mexico                    67.0
# 32          1068.0              New York                    27.0
# 33          1098.0        North Carolina                   100.0
# 34          1283.0          North Dakota                    98.0
# 35          1099.0                  Ohio                   100.0
# 36          1062.0              Oklahoma                   100.0
# 37          1117.0                Oregon                    42.0
# 38          1086.0          Pennsylvania                    20.0
# 39          1018.0          Rhode Island                    15.0
# 40          1070.0        South Carolina                   100.0
# 41          1240.0          South Dakota                    77.0
# 42          1231.0             Tennessee                   100.0
# 43          1032.0                 Texas                    41.0
# 44          1010.0                  Utah                   100.0
# 45          1120.0               Vermont                    24.0
# 46          1117.0              Virginia                    24.0
# 47          1081.0            Washington                    24.0
# 48           999.0         West Virginia                    65.0
# 49          1294.0             Wisconsin                   100.0
# 50          1257.0               Wyoming                   100.0
#
#     composite_act_2018  english_act_2018  math_act_2018 reading_act_2018  \
# 0                 19.1              18.9           18.3             19.6
# 1                 20.8              19.8           20.6             21.6
# 2                 19.2              18.2           19.4             19.5
# 3                 19.4              19.1           18.9             19.7
# 4                 22.7              22.5           22.5             23.0
# 5                 23.9              23.9           23.2             24.4
# 6                 25.6              26.0           24.8             26.1
# 7                 23.2              23.7           23.1             24.5
# 8                 23.6              23.7           22.7             24.4
# 9                 19.9              19.2           19.3             21.1
# 10                21.4              20.9           20.7             21.2
# 11                18.9              18.2           19.0             19.1
# 12                22.3              21.9           21.6             23.2
# 13                23.9              24.1           23.4             24.2
# 14                22.5              21.9           22.3             23.1
# 15                21.8              21.0           21.2             22.5
# 16                21.6              21.0           21.1             22.3
# 17                20.2              19.9           19.7             20.8
# 18                19.2              19.0           18.5             19.6
# 19                24.0              23.8           23.6             24.7
# 20                22.5              22.1           22.0             23.1
# 21                25.5              25.5           25.2             25.9
# 22                24.4              24.5           23.9             24.7
# 23                21.3              20.2           21.4             21.7
# 24                18.6              18.2           18.1             18.9
# 25                20.0              19.5           19.7             20.5
# 26                20.0              18.7           19.9             20.7
# 27                20.1              19.4           19.8             20.4
# 28                17.7              16.6           17.8             18.0
# 29                25.1              25.1           24.7             25.6
# 30                23.7              23.8           23.6             24.0
# 31                19.4              18.3           19.1             20.1
# 32                24.5              24.2           24.2             24.9
# 33                19.1              18.0           19.3             19.5
# 34                20.3              19.1           20.3             20.7
# 35                20.3              19.3           20.3             20.8
# 36                19.3              18.4           18.8             20.1
# 37                21.3              20.6           20.9             21.9
# 38                23.5              23.3           23.2             24.0
# 39                24.2              24.4           23.6             25.0
# 40                18.3              17.3           18.2             18.6
# 41                21.9              20.8           21.6             22.4
# 42                19.6              19.4           19.1             19.9
# 43                20.6              19.6           20.6             21.1
# 44                20.4              19.7           19.9             20.9
# 45                24.1              23.9           23.4             24.9
# 46                23.9              23.8           23.3             24.7
# 47                22.2              21.4           22.2             22.7
# 48                20.3              19.8           19.4             21.3
# 49                20.5              19.8           20.3             20.6
# 50                20.0              19.0           19.7             20.6
#
#     science_act_2018  verbal_act_2017
# 0               19.0             38.6
# 1               20.7             39.1
# 2               19.2             38.7
# 3               19.4             38.6
# 4               22.1             45.6
# 5               23.5             41.3
# 6               24.9             51.1
# 7               23.4             48.9
# 8               23.0             49.3
# 9               19.5             40.0
# 10              21.4             43.0
# 11              19.0             37.0
# 12              22.1             44.9
# 13              23.4             42.6
# 14              22.2             45.2
# 15              22.0             43.8
# 16              21.5             43.4
# 17              20.1             40.1
# 18              19.1             39.2
# 19              23.4             49.0
# 20              22.2             47.5
# 21              24.7             51.3
# 22              23.9             48.6
# 23              21.4             42.2
# 24              18.6             37.0
# 25              20.0             40.6
# 26              20.0             40.0
# 27              20.1             42.8
# 28              17.9             34.4
# 29              24.4             51.4
# 30              23.0             47.9
# 31              19.7             39.0
# 32              24.2             48.4
# 33              19.2             37.4
# 34              20.5             39.5
# 35              20.4             43.7
# 36              19.4             38.6
# 37              21.1             43.6
# 38              23.1             47.6
# 39              23.5             48.7
# 40              18.5             36.6
# 41              22.2             43.0
# 42              19.6             39.6
# 43              20.8             40.6
# 44              20.5             40.3
# 45              23.8             47.7
# 46              23.5             48.1
# 47              22.0             43.0
# 48              20.4             41.2
# 49              20.8             40.3
# 50              20.3             40.2
#
# [51 rows x 25 columns]

# %%
from scipy import stats

# %%
# p value less than alpha 0.05 data math_act_2017 dont follow a normal distribution this is the ebrw score of sat 2017
print(stats.normaltest(merged_final["total_sat_2017"]))
# Out:
# NormaltestResult(statistic=9.607185954097002, pvalue=0.008200230814088539)

# %%
# pvalue less than 0.05 do not follow a normal distribution this is the total mean sat score of sat 2018

print(stats.normaltest(merged_final["total_sat_2018"]))
# Out:
# NormaltestResult(statistic=8.459129644249382, pvalue=0.014558724804979849)

# %%
# pvalue less than 0.05 do not follow a normal distribution this is the total mean composite score of ACT 2017
print(stats.normaltest(merged_final["composite_act_2017"]))
# Out:
# NormaltestResult(statistic=6.557389886662569, pvalue=0.03767739587231253)

# %%
# pvalue less than 0.05 do not follow a normal distribution this is the total mean composite score of ACT 2018
print(stats.normaltest(merged_final["composite_act_2018"]))
# Out:
# NormaltestResult(statistic=8.70683791505615, pvalue=0.012862760086159716)

# %% [markdown]
# Answers: Answers: Based on all the plots as well as a quick glance over the summary statistics of the numeric columns. It can be concluded that the participation rates do not follow a normal distribution. It has a high standard deviation that is caused by mandatory state requirements as well as a choice among students to take one over the other. It is difficult in this case to have any inference other than it having a bimodal distribution. This means that either students are mandated to take the ACT test on one hand then there will be low participation on ACT test likewise for states mandated to take the SAT test, resulting in a bimodal distribution. The standard deviation is huge and the mean is not accurate. All the test scores follow a rather controlled standard deviation of 5-10% of the mean which is understandable to maintain the reliability of the tests year on year. While it should approximate to a normal distribution, it also shows a bimodal distribution where there are students who are more motivated and prepared (likely from independent test takers who are not mandated) as well as those who are unprepared. The risk of modelling a normal distribution for the test scores in either test is that higher performing students will find it harder to get a good score and lower performing students will find it easier to obtain a better grade. Therefore, on the respective official test sites, they do state they get a range of values from 'past' data which likely comes from the bimodal distribution instead of a normal one.

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
f, axes = plt.subplots(1, 2, figsize=(10,4))

sns.distplot(merged_final['math_act_2017'], bins=5, ax=axes[0]);
sns.distplot(merged_final['math_act_2018'], bins=5, ax=axes[1]);

# %%
f, axes = plt.subplots(1, 2, figsize=(10,4))

sns.distplot(merged_final['reading_act_2017'], bins=5, ax=axes[0]);
sns.distplot(merged_final['reading_act_2018'], bins=5, ax=axes[1]);

# %%
f, axes = plt.subplots(1, 2, figsize=(10,4))

sns.distplot(merged_final['participation_act_2017'], bins=5, ax=axes[0]);
sns.distplot(merged_final['participation_act_2018'], bins=5, ax=axes[1]);

# %% [markdown]
# Answer:Based on these distributions, it does not look like a normal distribution. seems the distribution isnt normal.Does not follow a normal distribution curve.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:Answer: Yes, there is a relationship between SAT and ACT participation rates where the correlation based on the heat map is -0.84. This makes sense for people who wish to swap tests to SAT maybe because of mandatory state requirements or personal choice.it is closely negatively correlated to 1.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Answer: It is not appropriate because both scores are on a different scale. They show no correlation and they are done mostly by different students. i.e. those who take ACT likely wont take SAT, so despite them likely to show a normal distribution on its own, they cannot be compared value to value without an appropriate conversion scale.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Ohio paid for all students to take the ACT test in 2018 hence participation rate went up to 100. This is a 25% change. source: [https://www.daytondailynews.com/news/historically-low-act-scores-red-flag-for-our-country/djfx9Urp719WyEaMfykyxL/]
#
# Nebraska was state mandated in 2018. It was already high to start with hence only a 16% change. source: [https://www.education.ne.gov/assessment/act/]
#
# Colorado also state mandated SAT and highlighted one of the biggest shifts from ACT to SAT tests with a change of 900% (if we look at it from 11% to 100% participation rate) source: [https://www.testive.com/colorado-sat-change-2017/]
#
# SAT has more people taking the test as seen from the mean. Despite the box plot showing otherwise, this might be because despite the participation rates for the states taking the ACT test may be lesser populated. The box plot only shows the percentage but the actual proportion depends on the states itself. Hence it is expected that the number of students taking each test is about the same with SAT exceeding the students taking ACT according to this link below.
#
# source: [https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/?noredirect=on&utm_term=.ae7de6e393cf]

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Key takeaways:
#
# High participation -> lower average scores.
#
# Also if the SAT participation rate is high in the state, the ACT has a low participation rate, thus strong but negatively correlated.
#
# We have a two pronged approadh for increasing SAT Participation rates for states.
#
#
# One we aim to increase the participation rates which are low for SAT being Iowa, Kansas 3-4% but not 100% ACT rates,
# therefore its not mandated to take ACT scores in the states. Which we will push for them to adopt SAT scores ,covering part or all of SAT exam fees.
#
# Secondly a long term approach will be to lobby for states to adopt SAT scores and not ACT scores ,which we will target the large states with a 100% ACT psrticipation rate and wait for the multi year contracts to end.
#
#
# If theres a high participation rate in SAT , it has a low mean score.
#
# Waiver the fees for SAT for lower income participants to increase participation rate.
# https://www.collegeboard.org/releases/2018/more-than-2-million-students-in-class-of-2018-took-sat-highest-ever
#
# Give free personalized practice.
#
# Data from 2017 reveal that 20 hours of practice using OSP on Khan Academy is associated with an average 115-point increase from the PSAT/NMSQT to the SAT. That's double the score gain of students who didn't use Official SAT Practice.
#
#
#
#  Covering all or part of exam fees: fee waivers are available for low‐income students,
# particularly those to whom exam fees would present an undue burden.3 The College
# Board also provides a free tool for school counselors to track students’ progress in
# registering for the SAT and using fee waivers.4 The College Board reports that fee
# waivers are more common than ever and supported 23 percent of SAT takers in
# 2013.5 However, obtaining a fee waiver does not guarantee test participation. The
# College Board found that the two most common reasons for test day absenteeism
# among fee‐waiver recipients were 1) feeling unprepared and 2) not having
# transportation. Fee‐waiver recipients indicated that the school counselor was the
# most important influence in deciding whether to register, and they would have been
#
#
#  Offering the SAT during regular school hours: SAT School Day, an initiative first
# offered in 2010, helps states and school districts foster a culture of college interest
# by increasing access. Students take the SAT for free, during the school day, reducing
# potential Saturday testing barriers (e.g., part‐time jobs, family responsibilities). In
# 2014, SAT School Day will be offered to all junior and senior public school students
# in more than 60 districts, 14 states, and the District of Columbia.
#  Increasing access to the PSAT/NMSQT®: performance on the Preliminary
# SAT/National Merit Scholarship Qualifying Test (PSAT/NMSQT) is one of the
# strongest predictors of AP success, so increasing participation will identify more
# students who should be enrolled in AP courses.
#  Expanding access to honors and AP courses: students who meet the SAT College
# and Career Readiness Benchmark (a score of 1550 or higher) are more likely to have
# taken advanced coursework.
#  Targeting high‐achieving, low‐income students: providing disadvantaged but highly
# achieving students with customized college information will provide them with
# information to better identify more selective higher education institutions.
#
# Choose to market the test as having a higher average score as compared to other states, which helps students who would like to use this test score at a state where this test is mandated. For example, ACT mandated states' students take SAT and use SAT score to enter a college in a state that is SAT mandated.
